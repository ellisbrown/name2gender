# %%
import random
import csv
import string
import math
import nltk
from nltk.corpus import names
from nltk.classify import apply_features
import numpy as np
# import torch
# import torch.nn as nn

# %%
def loadNames():
    filename = "namedata.csv"
    names = []
    genders = []
 
    with open(filename) as csvDataFile:
        csvReader = csv.reader(csvDataFile)
        for row in csvReader:
            names.append(row[0])
            genders.append(row[1])

    return names, genders

def loadDataset(shuffled=True):
    """Returns the name->gender dataset ready for processing
    
    Args:
        shuffled (Boolean, optional): set to False to return the dataset unshuffled
    Ret:
        namelist (list(String,String)): list of (name, gender) records
    """
    nms,gns = loadNames()
    namelist = list(zip(nms,gns))
    if shuffled:
        random.shuffle(namelist)
    return namelist

# %%
def _gender_features(name):
    features = {}
    features["last_letter"] = name[-1].lower()
    features["first_letter"] = name[0].lower()
    for letter in string.ascii_lowercase:
        features["count(%s)" % letter] = name.lower().count(letter)
        features["has(%s)" % letter] = (letter in name.lower())
    # names ending in -yn are mostly female, names ending in -ch ar mostly male, so add 2 more features
    features["suffix2"] = name[-2:]
    features["suffix3"] = name[-3:]
    return features

# %%
def naive_bayes_gender_classifier(train):
    """trains classifier on name->gender
    
    Args:
        train: % of examples to train with (e.g., 0.8)
    """
    
    # get name lists
    labeled_names = namelist.copy()
    random.shuffle(labeled_names)
    
    divider = int(len(labeled_names) * train)
    train_set = apply_features(_gender_features, labeled_names[divider:])
    test_set = apply_features(_gender_features, labeled_names[:divider])
    
    classifier = nltk.NaiveBayesClassifier.train(train_set)
    acc = nltk.classify.accuracy(classifier, test_set)
    print("test: " + str(train) + ", acc: " + str(acc))
#     classifier.show_most_informative_features(5)
    return acc

# %%
naive_bayes_gender_classifier(0.5)
# Out:
# test: 0.5, acc: 0.8066465256797583
# 0.8066465256797583

# %%
accuracies = {}
for i in range(50,85,5):
    cum = 0
    num = 10
    for j in range(num):
        cum += naive_bayes_gender_classifier(i * 0.01)
    accuracies[i] = cum / num
# Out:
# test: 0.5, acc: 0.8006042296072508
# test: 0.5, acc: 0.7993454179254783
# test: 0.5, acc: 0.8011077542799597
# test: 0.5, acc: 0.8071500503524672
# test: 0.5, acc: 0.8021148036253777
# test: 0.5, acc: 0.8026183282980867
# test: 0.5, acc: 0.8086606243705942
# test: 0.5, acc: 0.8036253776435045
# test: 0.5, acc: 0.7990936555891238
# test: 0.5, acc: 0.8079053373615307
# test: 0.55, acc: 0.7956054016937514
# test: 0.55, acc: 0.79995422293431
# test: 0.55, acc: 0.7965209430075532
# test: 0.55, acc: 0.7983520256351568
# test: 0.55, acc: 0.8024719615472649
# test: 0.55, acc: 0.7946898603799496
# test: 0.55, acc: 0.8006408789196613
# test: 0.55, acc: 0.7930876630807965
# test: 0.55, acc: 0.7985809109636073
# test: 0.55, acc: 0.7910276951247425
# test: 0.6, acc: 0.7958455728073857
# test: 0.6, acc: 0.7933277381451951
# test: 0.6, acc: 0.8006714225765842
# test: 0.6, acc: 0.7983634074695761
# test: 0.6, acc: 0.8006714225765842
# test: 0.6, acc: 0.7968946705832983
# test: 0.6, acc: 0.8017205203524969
# test: 0.6, acc: 0.7979437683592111
# test: 0.6, acc: 0.797524129248846
# test: 0.6, acc: 0.7989928661351238
# test: 0.65, acc: 0.7962424946736394
# test: 0.65, acc: 0.8043773000193686
# test: 0.65, acc: 0.8037962424946736
# test: 0.65, acc: 0.8053457292271935
# test: 0.65, acc: 0.799147782297114
# test: 0.65, acc: 0.7954677513073795
# test: 0.65, acc: 0.8034088708115437
# test: 0.65, acc: 0.7970172380398993
# test: 0.65, acc: 0.800116211504939
# test: 0.65, acc: 0.8053457292271935
# test: 0.7000000000000001, acc: 0.7967625899280576
# test: 0.7000000000000001, acc: 0.8037769784172661
# test: 0.7000000000000001, acc: 0.7893884892086331
# test: 0.7000000000000001, acc: 0.7951438848920863
# test: 0.7000000000000001, acc: 0.8030575539568345
# test: 0.7000000000000001, acc: 0.7982014388489208
# test: 0.7000000000000001, acc: 0.7969424460431654
# test: 0.7000000000000001, acc: 0.7953237410071943
# test: 0.7000000000000001, acc: 0.7942446043165468
# test: 0.7000000000000001, acc: 0.7965827338129496
# test: 0.75, acc: 0.7925478348439073
# test: 0.75, acc: 0.7814702920443102
# test: 0.75, acc: 0.7984222893588453
# test: 0.75, acc: 0.7829808660624371
# test: 0.75, acc: 0.8002685464921114
# test: 0.75, acc: 0.7987579724739846
# test: 0.75, acc: 0.793219201074186
# test: 0.75, acc: 0.7994293387042631
# test: 0.75, acc: 0.7972473984558577
# test: 0.75, acc: 0.7945619335347432
# test: 0.8, acc: 0.7973249409913454
# test: 0.8, acc: 0.7833202202989772
# test: 0.8, acc: 0.7951219512195122
# test: 0.8, acc: 0.7885129819040125
# test: 0.8, acc: 0.785837922895358
# test: 0.8, acc: 0.7867820613690008
# test: 0.8, acc: 0.7949645948072384
# test: 0.8, acc: 0.7955940204563337
# test: 0.8, acc: 0.789771833202203
# test: 0.8, acc: 0.7946498819826908

# %%
accuracies
# Out:
# {50: 0.8032225579053373,
#  55: 0.7970931563286793,
#  60: 0.7981955518254302,
#  65: 0.8010265349602944,
#  70: 0.7969424460431654,
#  75: 0.7938905673044647,
#  80: 0.7911880409126673}

# %%
male_names = names.words('male.txt')
female_names = names.words('female.txt')
labeled_names = ([(name, 'male') for name in male_names] + [(name, 'female') for name in female_names])

# %%
len(labeled_names)
# Out:
# 7944

# %%
# classify a single person's name
male_names = names.words('male.txt')
female_names = names.words('female.txt')
labeled_names = ([(name, 'male') for name in male_names] + [(name, 'female') for name in female_names])
random.shuffle(labeled_names)

divider = int(60)
train_set = apply_features(_gender_features, labeled_names[divider:])
test_set = apply_features(_gender_features, labeled_names[:divider])

classifier = nltk.NaiveBayesClassifier.train(train_set)


classifier.classify(_gender_features("alex"))
# Out:
# 'male'

# %%
type(labeled_names)
# Out:
# list

# %%
# Out:
# [('ginnifer', 'female'),
#  ('veer', 'male'),
#  ('agustya', 'male'),
#  ('jaheam', 'male'),
#  ('kesly', 'female'),
#  ('sreehan', 'male'),
#  ('ernisha', 'female'),
#  ('mirjam', 'female'),
#  ('perna', 'female'),
#  ('kylematthew', 'male'),
#  ('deshone', 'male'),
#  ('ajisha', 'female'),
#  ('dezhan', 'male'),
#  ('sevryn', 'male'),
#  ('foppe', 'male'),
#  ('thinh', 'male'),
#  ('saniyah', 'female'),
#  ('brityn', 'female'),
#  ('tekeira', 'female'),
#  ('avry', 'female'),
#  ('annunziato', 'male'),
#  ('lizeht', 'female'),
#  ('alcdia', 'female'),
#  ('gurlie', 'female'),
#  ('reeya', 'female'),
#  ('vinay', 'male'),
#  ('seoyoon', 'female'),
#  ('evisa', 'female'),
#  ('renado', 'male'),
#  ('miyona', 'female'),
#  ('vaira', 'female'),
#  ('rupi', 'female'),
#  ('aella', 'female'),
#  ('dagbjrt', 'female'),
#  ('mairtn', 'male'),
#  ('konstantinos', 'male'),
#  ('shadee', 'female'),
#  ('augustis', 'male'),
#  ('chanden', 'male'),
#  ('gearald', 'male'),
#  ('shaunea', 'female'),
#  ('treton', 'male'),
#  ('yishu', 'male'),
#  ('darrlyn', 'male'),
#  ('cashion', 'male'),
#  ('dekin', 'male'),
#  ('ophelia', 'male'),
#  ('xialin', 'male'),
#  ('leran', 'female'),
#  ('josealfredo', 'male'),
#  ('chunghsiung', 'male'),
#  ('clevester', 'male'),
#  ('hatixhe', 'female'),
#  ('youqin', 'male'),
#  ('melwin', 'male'),
#  ('neosha', 'female'),
#  ('analiyah', 'female'),
#  ('suraya', 'female'),
#  ('pawnee', 'female'),
#  ('najmah', 'female'),
#  ('xiumei', 'male'),
#  ('miriama', 'female'),
#  ('chieu', 'male'),
#  ('rhylea', 'female'),
#  ('wenchao', 'male'),
#  ('dejuane', 'male'),
#  ('starling', 'male'),
#  ('pacey', 'male'),
#  ('marieka', 'female'),
#  ('selinde', 'female'),
#  ('lanjin', 'male'),
#  ('chaneice', 'female'),
#  ('addsion', 'female'),
#  ('kyerstin', 'female'),
#  ('forida', 'female'),
#  ('kamia', 'female'),
#  ('amechi', 'male'),
#  ('munir', 'male'),
#  ('eldana', 'female'),
#  ('serani', 'male'),
#  ('night', 'female'),
#  ('brittanae', 'female'),
#  ('sadeq', 'male'),
#  ('briyon', 'male'),
#  ('gisel', 'female'),
#  ('ninagiovanna', 'male'),
#  ('tynise', 'female'),
#  ('minaksi', 'male'),
#  ('shikari', 'female'),
#  ('deva', 'female'),
#  ('radita', 'female'),
#  ('merika', 'female'),
#  ('jacobmatthew', 'male'),
#  ('lakedrick', 'male'),
#  ('chanele', 'female'),
#  ('treshaun', 'male'),
#  ('aleighanna', 'female'),
#  ('mileydi', 'female'),
#  ('tiembinus', 'male'),
#  ('freimut', 'male'),
#  ('kasai', 'male'),
#  ('younjoo', 'female'),
#  ('farudin', 'male'),
#  ('fitzhugh', 'male'),
#  ('sarriyah', 'female'),
#  ('edela', 'female'),
#  ('emilo', 'male'),
#  ('zhengtao', 'male'),
#  ('mialee', 'female'),
#  ('nitaya', 'female'),
#  ('hulene', 'female'),
#  ('shavonn', 'female'),
#  ('cheridan', 'female'),
#  ('rip', 'male'),
#  ('yosmar', 'male'),
#  ('chaena', 'female'),
#  ('fransisca', 'female'),
#  ('sidika', 'female'),
#  ('garv', 'male'),
#  ('garyon', 'male'),
#  ('quyet', 'male'),
#  ('airyonna', 'female'),
#  ('mrinal', 'female'),
#  ('roxxi', 'female'),
#  ('araf', 'male'),
#  ('taddeo', 'male'),
#  ('novaya', 'female'),
#  ('lataija', 'female'),
#  ('daleesa', 'female'),
#  ('tranquilla', 'female'),
#  ('ambroziu', 'male'),
#  ('luiggi', 'male'),
#  ('sueelle', 'female'),
#  ('yakeem', 'male'),
#  ('skylarrose', 'female'),
#  ('onalee', 'female'),
#  ('aquila', 'female'),
#  ('harlei', 'female'),
#  ('hrmar', 'male'),
#  ('marvia', 'female'),
#  ('zophie', 'female'),
#  ('marsue', 'female'),
#  ('cordey', 'male'),
#  ('naut', 'male'),
#  ('ibbo', 'male'),
#  ('mikemichael', 'male'),
#  ('manson', 'male'),
#  ('hydia', 'female'),
#  ('azelene', 'female'),
#  ('deshawnna', 'female'),
#  ('tauheedah', 'female'),
#  ('lolkje', 'female'),
#  ('aryk', 'male'),
#  ('kassiah', 'female'),
#  ('michiru', 'female'),
#  ('atalay', 'male'),
#  ('mekyla', 'female'),
#  ('heingert', 'male'),
#  ('jingdong', 'male'),
#  ('kiwana', 'female'),
#  ('sucely', 'female'),
#  ('heinie', 'female'),
#  ('zayuri', 'female'),
#  ('refki', 'male'),
#  ('yuko', 'male'),
#  ('camrun', 'male'),
#  ('bitte', 'female'),
#  ('lavie', 'female'),
#  ('clesta', 'female'),
#  ('heiko', 'male'),
#  ('rosenia', 'female'),
#  ('dongxiang', 'male'),
#  ('ianthus', 'male'),
#  ('rece', 'male'),
#  ('erlgard', 'female'),
#  ('aliyiah', 'female'),
#  ('ellorie', 'female'),
#  ('fantaysia', 'female'),
#  ('ehren', 'male'),
#  ('nasheem', 'male'),
#  ('cordel', 'male'),
#  ('tren', 'male'),
#  ('rumyanka', 'female'),
#  ('lujane', 'female'),
#  ('jisiah', 'male'),
#  ('brayanna', 'female'),
#  ('saschaaleksandr', 'male'),
#  ('raven', 'female'),
#  ('heorhi', 'male'),
#  ('adaja', 'female'),
#  ('basimah', 'female'),
#  ('edvige', 'female'),
#  ('shandra', 'female'),
#  ('wingate', 'male'),
#  ('debriana', 'female'),
#  ('shenea', 'female'),
#  ('zilin', 'female'),
#  ('deiona', 'female'),
#  ('rejina', 'female'),
#  ('shutao', 'male'),
#  ('subeda', 'female'),
#  ('theodoula', 'female'),
#  ('samorah', 'female'),
#  ('lovelyn', 'female'),
#  ('qiqiang', 'male'),
#  ('malaeka', 'female'),
#  ('maimo', 'female'),
#  ('divansh', 'male'),
#  ('annekatrin', 'female'),
#  ('ovida', 'female'),
#  ('dzenana', 'female'),
#  ('fenn', 'male'),
#  ('dazhan', 'male'),
#  ('yadian', 'male'),
#  ('tomoki', 'male'),
#  ('zeylah', 'female'),
#  ('ruhong', 'male'),
#  ('leylany', 'female'),
#  ('winnefred', 'female'),
#  ('priscyla', 'female'),
#  ('jerine', 'female'),
#  ('zhiguo', 'male'),
#  ('carlyann', 'female'),
#  ('uless', 'male'),
#  ('ruzica', 'female'),
#  ('bralyn', 'male'),
#  ('pirkko', 'female'),
#  ('amilliona', 'female'),
#  ('grey', 'male'),
#  ('shametria', 'female'),
#  ('sabreea', 'female'),
#  ('zoe', 'female'),
#  ('dajanay', 'female'),
#  ('bobbye', 'female'),
#  ('keally', 'female'),
#  ('leiasia', 'female'),
#  ('rosezanna', 'female'),
#  ('asle', 'male'),
#  ('jerrolyn', 'female'),
#  ('jehoshua', 'male'),
#  ('octavie', 'female'),
#  ('xuelin', 'male'),
#  ('jacobje', 'female'),
#  ('eiza', 'female'),
#  ('angeliina', 'female'),
#  ('strickland', 'male'),
#  ('avenly', 'female'),
#  ('khelani', 'female'),
#  ('zephram', 'male'),
#  ('jinkyong', 'female'),
#  ('coleta', 'female'),
#  ('ervena', 'female'),
#  ('arlana', 'female'),
#  ('maleki', 'male'),
#  ('preksha', 'female'),
#  ('auschvidas', 'male'),
#  ('jingting', 'female'),
#  ('gnsel', 'female'),
#  ('akieba', 'female'),
#  ('malenny', 'female'),
#  ('heloisa', 'female'),
#  ('raakkeli', 'female'),
#  ('machi', 'female'),
#  ('jillena', 'female'),
#  ('ailsa', 'female'),
#  ('shuzhen', 'male'),
#  ('mackenlee', 'female'),
#  ('alnora', 'female'),
#  ('prabha', 'female'),
#  ('mercan', 'male'),
#  ('marven', 'male'),
#  ('chas', 'male'),
#  ('sinatra', 'male'),
#  ('sajad', 'male'),
#  ('gus', 'male'),
#  ('aristotel', 'male'),
#  ('torge', 'male'),
#  ('kizi', 'female'),
#  ('errico', 'male'),
#  ('johann', 'male'),
#  ('ereny', 'female'),
#  ('sourish', 'male'),
#  ('caelainn', 'female'),
#  ('pasquina', 'female'),
#  ('krisha', 'female'),
#  ('hjalmer', 'male'),
#  ('chantai', 'female'),
#  ('brother', 'male'),
#  ('everlyse', 'female'),
#  ('geneta', 'female'),
#  ('mathura', 'female'),
#  ('matigan', 'female'),
#  ('shanterri', 'female'),
#  ('bridy', 'female'),
#  ('radomila', 'female'),
#  ('eftimita', 'female'),
#  ('kiril', 'male'),
#  ('demarrie', 'male'),
#  ('willfredo', 'male'),
#  ('ahleigha', 'female'),
#  ('kortny', 'female'),
#  ('kanai', 'male'),
#  ('terryana', 'female'),
#  ('jovannie', 'male'),
#  ('kyrianna', 'female'),
#  ('alieshia', 'female'),
#  ('paresh', 'male'),
#  ('quanzie', 'male'),
#  ('bernda', 'female'),
#  ('sande', 'male'),
#  ('auni', 'female'),
#  ('ephrim', 'male'),
#  ('nyveah', 'female'),
#  ('eirlys', 'female'),
#  ('crowell', 'male'),
#  ('keandrae', 'male'),
#  ('indyah', 'female'),
#  ('dravid', 'male'),
#  ('blayde', 'male'),
#  ('angelou', 'male'),
#  ('yongbo', 'male'),
#  ('grarde', 'female'),
#  ('tisa', 'female'),
#  ('aglar', 'male'),
#  ('alva', 'male'),
#  ('nkara', 'female'),
#  ('chyene', 'female'),
#  ('tramar', 'male'),
#  ('jamess', 'male'),
#  ('jacquelin', 'female'),
#  ('salvina', 'female'),
#  ('jaylond', 'male'),
#  ('joya', 'female'),
#  ('amiyiah', 'female'),
#  ('melmelanie', 'male'),
#  ('delton', 'male'),
#  ('majuma', 'female'),
#  ('baldvina', 'female'),
#  ('melo', 'male'),
#  ('gulnara', 'female'),
#  ('haines', 'male'),
#  ('feride', 'female'),
#  ('gracinda', 'female'),
#  ('chaoyang', 'male'),
#  ('kieva', 'female'),
#  ('duell', 'male'),
#  ('cambriah', 'female'),
#  ('soini', 'female'),
#  ('mohamedhalimbin', 'male'),
#  ('akura', 'female'),
#  ('romualds', 'male'),
#  ('namirah', 'female'),
#  ('javantay', 'male'),
#  ('arlynes', 'female'),
#  ('rockson', 'male'),
#  ('anaclara', 'female'),
#  ('maureena', 'female'),
#  ('yirui', 'male'),
#  ('breelynn', 'female'),
#  ('nouri', 'male'),
#  ('alecxa', 'female'),
#  ('dahe', 'male'),
#  ('zhair', 'male'),
#  ('josie', 'female'),
#  ('bingru', 'male'),
#  ('hajohansjoachim', 'male'),
#  ('zulfija', 'female'),
#  ('timarion', 'male'),
#  ('peggy', 'male'),
#  ('trevis', 'male'),
#  ('luisgerardo', 'male'),
#  ('doralin', 'female'),
#  ('zykeem', 'male'),
#  ('fenyu', 'male'),
#  ('kamara', 'female'),
#  ('shanoa', 'female'),
#  ('javed', 'male'),
#  ('keniel', 'male'),
#  ('pasquino', 'male'),
#  ('alius', 'male'),
#  ('mironica', 'female'),
#  ('shian', 'female'),
#  ('lanceton', 'male'),
#  ('myalin', 'female'),
#  ('atheana', 'female'),
#  ('dimitrija', 'male'),
#  ('borjanka', 'female'),
#  ('saroun', 'female'),
#  ('naryia', 'female'),
#  ('leshell', 'female'),
#  ('johnathen', 'male'),
#  ('rocelyn', 'female'),
#  ('lanaijah', 'female'),
#  ('etash', 'male'),
#  ('faylyn', 'female'),
#  ('maiquel', 'female'),
#  ('soila', 'female'),
#  ('laline', 'female'),
#  ('shaneice', 'female'),
#  ('massamba', 'male'),
#  ('heeya', 'female'),
#  ('johnnia', 'female'),
#  ('lydon', 'male'),
#  ('holleigh', 'female'),
#  ('alyeska', 'female'),
#  ('ionas', 'male'),
#  ('bernulf', 'male'),
#  ('gabina', 'female'),
#  ('meisje', 'female'),
#  ('mutlu', 'male'),
#  ('ameia', 'female'),
#  ('vashni', 'female'),
#  ('anaveah', 'female'),
#  ('zoeygrace', 'female'),
#  ('havva', 'female'),
#  ('zykierra', 'female'),
#  ('junathaen', 'male'),
#  ('balraj', 'male'),
#  ('traevin', 'male'),
#  ('jermane', 'male'),
#  ('laisheng', 'male'),
#  ('darthula', 'female'),
#  ('riobeard', 'male'),
#  ('kalib', 'male'),
#  ('lynnell', 'female'),
#  ('delci', 'female'),
#  ('akeena', 'female'),
#  ('bethsaida', 'female'),
#  ('sriskantharajah', 'male'),
#  ('nuhi', 'male'),
#  ('kamarien', 'male'),
#  ('rochanda', 'female'),
#  ('shaunee', 'female'),
#  ('illona', 'female'),
#  ('christfried', 'male'),
#  ('shambrica', 'female'),
#  ('minyoon', 'male'),
#  ('majida', 'female'),
#  ('maliss', 'female'),
#  ('belvin', 'male'),
#  ('miyake', 'male'),
#  ('zuleika', 'female'),
#  ('marjarie', 'female'),
#  ('neiko', 'male'),
#  ('glory', 'female'),
#  ('lakai', 'male'),
#  ('beda', 'male'),
#  ('starleigh', 'female'),
#  ('kaicee', 'female'),
#  ('chanell', 'female'),
#  ('lone', 'female'),
#  ('kathlena', 'female'),
#  ('levorne', 'male'),
#  ('remedi', 'female'),
#  ('elby', 'male'),
#  ('jura', 'female'),
#  ('kaedyn', 'male'),
#  ('viar', 'male'),
#  ('jogina', 'female'),
#  ('cristeen', 'female'),
#  ('albric', 'male'),
#  ('lyutcho', 'male'),
#  ('sanyia', 'female'),
#  ('harpergrace', 'female'),
#  ('reita', 'female'),
#  ('baldino', 'male'),
#  ('deztany', 'female'),
#  ('canasia', 'female'),
#  ('elyah', 'male'),
#  ('rishita', 'female'),
#  ('brano', 'male'),
#  ('milco', 'male'),
#  ('dominus', 'male'),
#  ('nollan', 'male'),
#  ('gytte', 'female'),
#  ('caithan', 'male'),
#  ('dasya', 'female'),
#  ('jakub', 'male'),
#  ('knightley', 'female'),
#  ('ulrich', 'male'),
#  ('shiliang', 'male'),
#  ('nafisa', 'female'),
#  ('shaelynne', 'female'),
#  ('zelva', 'female'),
#  ('nellie', 'female'),
#  ('nayli', 'female'),
#  ('mohinder', 'male'),
#  ('ilvis', 'male'),
#  ('akeil', 'male'),
#  ('chev', 'male'),
#  ('rohit', 'male'),
#  ('kilea', 'female'),
#  ('irbin', 'male'),
#  ('arti', 'male'),
#  ('heimhart', 'male'),
#  ('geralyn', 'female'),
#  ('chuy', 'male'),
#  ('dareus', 'male'),
#  ('petina', 'female'),
#  ('lianhua', 'male'),
#  ('anibella', 'female'),
#  ('eban', 'male'),
#  ('friedric', 'male'),
#  ('bland', 'male'),
#  ('viigo', 'male'),
#  ('velitchka', 'female'),
#  ('jondavid', 'male'),
#  ('agazio', 'male'),
#  ('dearie', 'female'),
#  ('inesis', 'male'),
#  ('isidro', 'male'),
#  ('cisely', 'female'),
#  ('kang', 'female'),
#  ('spandana', 'female'),
#  ('srbin', 'male'),
#  ('malikai', 'male'),
#  ('gugash', 'male'),
#  ('gottfried', 'male'),
#  ('kamaljit', 'male'),
#  ('kaymen', 'male'),
#  ('savonia', 'female'),
#  ('lrro', 'male'),
#  ('twilah', 'female'),
#  ('krieno', 'male'),
#  ('mekkah', 'female'),
#  ('rivan', 'male'),
#  ('nylani', 'female'),
#  ('marlan', 'male'),
#  ('jahzel', 'female'),
#  ('allyce', 'female'),
#  ('denny', 'male'),
#  ('roan', 'male'),
#  ('tilesha', 'female'),
#  ('taavi', 'male'),
#  ('chrysovalanti', 'female'),
#  ('anabel', 'female'),
#  ('drusiana', 'female'),
#  ('friedeborg', 'female'),
#  ('gianmichele', 'male'),
#  ('alwilda', 'female'),
#  ('izaias', 'male'),
#  ('alahni', 'female'),
#  ('aleiyah', 'female'),
#  ('lupie', 'female'),
#  ('ilani', 'female'),
#  ('heejoo', 'female'),
#  ('shaquetta', 'female'),
#  ('nayelin', 'female'),
#  ('moudie', 'female'),
#  ('gizi', 'female'),
#  ('zarana', 'female'),
#  ('kip', 'male'),
#  ('krenare', 'female'),
#  ('jesucita', 'female'),
#  ('noreli', 'female'),
#  ('mikos', 'male'),
#  ('makensey', 'female'),
#  ('jungyul', 'male'),
#  ('teruko', 'female'),
#  ('manique', 'female'),
#  ('zamiere', 'male'),
#  ('alve', 'male'),
#  ('souhair', 'female'),
#  ('jernya', 'female'),
#  ('brindin', 'male'),
#  ('taghrid', 'female'),
#  ('daschena', 'female'),
#  ('fadil', 'male'),
#  ('brijin', 'female'),
#  ('renitha', 'female'),
#  ('bethlielisabeth', 'male'),
#  ('likisha', 'female'),
#  ('xyana', 'female'),
#  ('ivajlo', 'male'),
#  ('thurayya', 'female'),
#  ('abdurrehman', 'male'),
#  ('leodegario', 'male'),
#  ('iolanda', 'female'),
#  ('herlin', 'male'),
#  ('mirjanka', 'female'),
#  ('slvi', 'female'),
#  ('jeffray', 'male'),
#  ('avenell', 'female'),
#  ('taahirah', 'female'),
#  ('micahya', 'female'),
#  ('zhengjie', 'male'),
#  ('michaelynn', 'female'),
#  ('caydence', 'female'),
#  ('aretha', 'female'),
#  ('coralia', 'female'),
#  ('marju', 'female'),
#  ('venis', 'female'),
#  ('davene', 'female'),
#  ('damir', 'male'),
#  ('zhenyaevgenija', 'male'),
#  ('ashana', 'female'),
#  ('yaismanuel', 'male'),
#  ('hoss', 'male'),
#  ('maizie', 'female'),
#  ('dazjah', 'female'),
#  ('areg', 'male'),
#  ('ebru', 'female'),
#  ('aliviana', 'female'),
#  ('kinsie', 'female'),
#  ('maozhen', 'male'),
#  ('zaima', 'female'),
#  ('gylfi', 'male'),
#  ('yasiris', 'female'),
#  ('lajaune', 'male'),
#  ('eloisa', 'female'),
#  ('franco', 'male'),
#  ('gevalia', 'female'),
#  ('sammeul', 'male'),
#  ('dominike', 'female'),
#  ('lewsong', 'male'),
#  ('lamontray', 'male'),
#  ('lynsie', 'female'),
#  ('colbi', 'female'),
#  ('arkell', 'male'),
#  ('jds', 'female'),
#  ('gildas', 'male'),
#  ('zadarius', 'male'),
#  ('myungsook', 'female'),
#  ('zahmere', 'male'),
#  ('daniette', 'female'),
#  ('jaicyon', 'male'),
#  ('gebkea', 'female'),
#  ('trevona', 'female'),
#  ('greisy', 'female'),
#  ('jenie', 'female'),
#  ('zaragoza', 'male'),
#  ('haowei', 'male'),
#  ('eudoxie', 'female'),
#  ('kamal', 'male'),
#  ('eftim', 'male'),
#  ('allam', 'male'),
#  ('imalay', 'female'),
#  ('zyrjeta', 'female'),
#  ('saviel', 'male'),
#  ('shatoni', 'female'),
#  ('dessarae', 'female'),
#  ('jenna', 'female'),
#  ('shandy', 'female'),
#  ('djeni', 'female'),
#  ('oreda', 'female'),
#  ('miaja', 'female'),
#  ('aleyna', 'female'),
#  ('graceyn', 'female'),
#  ('tennyson', 'male'),
#  ('yadong', 'male'),
#  ('surie', 'female'),
#  ('yarenys', 'female'),
#  ('hongzi', 'male'),
#  ('wendie', 'female'),
#  ('pavithra', 'female'),
#  ('dax', 'male'),
#  ('riki', 'male'),
#  ('maynord', 'male'),
#  ('yashar', 'male'),
#  ('nawana', 'female'),
#  ('mariliis', 'female'),
#  ('nete', 'female'),
#  ('greenwood', 'male'),
#  ('aydree', 'female'),
#  ('anavaeh', 'female'),
#  ('richierichard', 'male'),
#  ('ravendran', 'male'),
#  ('khamphiou', 'female'),
#  ('urosch', 'male'),
#  ('keanah', 'female'),
#  ('mlynn', 'female'),
#  ('suheyb', 'male'),
#  ('jkobi', 'male'),
#  ('juliahna', 'female'),
#  ('daquane', 'male'),
#  ('leonelle', 'female'),
#  ('jenabelle', 'female'),
#  ('odet', 'female'),
#  ('ulesses', 'male'),
#  ('mufinella', 'female'),
#  ('adaya', 'female'),
#  ('helmtraud', 'female'),
#  ('bonnitta', 'female'),
#  ('kimley', 'female'),
#  ('carr', 'male'),
#  ('aimei', 'male'),
#  ('hari', 'male'),
#  ('arnlaugur', 'male'),
#  ('wenlei', 'male'),
#  ('jerol', 'male'),
#  ('avaah', 'female'),
#  ('jcyon', 'male'),
#  ('karielys', 'female'),
#  ('ejlif', 'male'),
#  ('dezerey', 'female'),
#  ('dawson', 'male'),
#  ('adon', 'male'),
#  ('chongjiu', 'male'),
#  ('yoshinari', 'male'),
#  ('roxey', 'female'),
#  ('jaydalise', 'female'),
#  ('shoney', 'female'),
#  ('brianalee', 'female'),
#  ('bodi', 'male'),
#  ('layra', 'female'),
#  ('yanghong', 'male'),
#  ('towanna', 'female'),
#  ('emyia', 'female'),
#  ('sharmila', 'female'),
#  ('chenlong', 'male'),
#  ('changjiang', 'male'),
#  ('roobert', 'male'),
#  ('shallan', 'female'),
#  ('joeanna', 'female'),
#  ('barlina', 'female'),
#  ('colmon', 'male'),
#  ('teiah', 'female'),
#  ('barbel', 'female'),
#  ('jassem', 'male'),
#  ('zugui', 'male'),
#  ('chiffon', 'female'),
#  ('pearline', 'female'),
#  ('lence', 'female'),
#  ('moneta', 'female'),
#  ('nahrain', 'female'),
#  ('xamara', 'female'),
#  ('elizjah', 'male'),
#  ('griffith', 'male'),
#  ('leannah', 'female'),
#  ('lukretziya', 'female'),
#  ('leeum', 'male'),
#  ('uro', 'male'),
#  ('roeli', 'female'),
#  ('farryn', 'female'),
#  ('lynniah', 'female'),
#  ('sharman', 'female'),
#  ('zula', 'female'),
#  ('meigo', 'male'),
#  ('laquaysha', 'female'),
#  ('aneudy', 'male'),
#  ('chanavia', 'female'),
#  ('mubina', 'female'),
#  ('mays', 'male'),
#  ('almagul', 'female'),
#  ('gabino', 'male'),
#  ('bitao', 'male'),
#  ('cirillo', 'male'),
#  ('samora', 'female'),
#  ('kovid', 'male'),
#  ('dilja', 'female'),
#  ('kujtesa', 'female'),
#  ('maquita', 'female'),
#  ('viktar', 'male'),
#  ('valancia', 'female'),
#  ('yorleny', 'female'),
#  ('rafail', 'male'),
#  ('filuta', 'female'),
#  ('dariene', 'female'),
#  ('raeniyah', 'female'),
#  ('ameyalli', 'female'),
#  ('shauntia', 'female'),
#  ('ermnia', 'female'),
#  ('lashema', 'female'),
#  ('traven', 'male'),
#  ('merilou', 'female'),
#  ('jayco', 'male'),
#  ('mahlik', 'male'),
#  ('chenwen', 'male'),
#  ('cai', 'male'),
#  ('murriel', 'female'),
#  ('catreena', 'female'),
#  ('ponce', 'male'),
#  ('keaka', 'male'),
#  ('sidiki', 'male'),
#  ('lajps', 'male'),
#  ('keiundra', 'female'),
#  ('madge', 'female'),
#  ('denee', 'female'),
#  ('tugra', 'male'),
#  ('taseen', 'male'),
#  ('darold', 'male'),
#  ('rifadije', 'female'),
#  ('rhun', 'male'),
#  ('hasanah', 'female'),
#  ('jessus', 'male'),
#  ('laneesha', 'female'),
#  ('alfonce', 'male'),
#  ('blessn', 'female'),
#  ('quillon', 'male'),
#  ('kennie', 'male'),
#  ('joory', 'female'),
#  ('kavisha', 'female'),
#  ('yashir', 'male'),
#  ('calian', 'male'),
#  ('noella', 'female'),
#  ('zhuyu', 'male'),
#  ('leighlan', 'male'),
#  ('johhny', 'male'),
#  ('vincenzino', 'male'),
#  ('brekkin', 'male'),
#  ('lockwood', 'male'),
#  ('zniah', 'female'),
#  ('povilas', 'male'),
#  ('huihong', 'male'),
#  ('holta', 'female'),
#  ('sriyaan', 'male'),
#  ('kingelijah', 'male'),
#  ('marterrius', 'male'),
#  ('mingmei', 'male'),
#  ('aminna', 'female'),
#  ('rakwon', 'male'),
#  ('zenzele', 'female'),
#  ('kama', 'female'),
#  ('kika', 'female'),
#  ('devarsh', 'male'),
#  ('euijung', 'female'),
#  ('hazal', 'female'),
#  ('octavious', 'male'),
#  ('estela', 'female'),
#  ('mariselda', 'female'),
#  ('stevens', 'male'),
#  ('semira', 'female'),
#  ('qunita', 'female'),
#  ('angieangela', 'male'),
#  ('vitcho', 'male'),
#  ('vigan', 'male'),
#  ('ariz', 'male'),
#  ('brone', 'female'),
#  ('hasret', 'female'),
#  ('ronmel', 'male'),
#  ('hrissonka', 'female'),
#  ('onke', 'male'),
#  ('xiaonan', 'male'),
#  ('binyuan', 'male'),
#  ('libny', 'female'),
#  ('jinlei', 'male'),
#  ('heneretta', 'female'),
#  ('jasuan', 'male'),
#  ('shivay', 'male'),
#  ('izick', 'male'),
#  ('keanthony', 'male'),
#  ('lehi', 'male'),
#  ('almonza', 'male'),
#  ('parv', 'male'),
#  ('lanelda', 'female'),
#  ('cairi', 'female'),
#  ('tylissa', 'female'),
#  ('dyke', 'male'),
#  ('nikkisha', 'female'),
#  ('viet', 'male'),
#  ('ethelmae', 'female'),
#  ('clive', 'male'),
#  ('jeffro', 'male'),
#  ('alexsouza', 'male'),
#  ('kimkimberly', 'male'),
#  ('vardan', 'male'),
#  ('shenicka', 'female'),
#  ('zosia', 'female'),
#  ('aatto', 'male'),
#  ('elaiya', 'female'),
#  ('takis', 'male'),
#  ('lupe', 'male'),
#  ('weijia', 'female'),
#  ('tarak', 'male'),
#  ('hutchinson', 'male'),
#  ('madax', 'male'),
#  ('ethyn', 'male'),
#  ('xuenong', 'male'),
#  ('thaddea', 'female'),
#  ('jubi', 'female'),
#  ('glinnie', 'female'),
#  ('aafia', 'female'),
#  ('jacarter', 'male'),
#  ('ronneisha', 'female'),
#  ('bryanna', 'female'),
#  ('perlina', 'female'),
#  ('yoojin', 'male'),
#  ('jalivia', 'female'),
#  ('travaughn', 'male'),
#  ('sunan', 'male'),
#  ('jyun', 'male'),
#  ('virgen', 'female'),
#  ('kireina', 'female'),
#  ('hughie', 'male'),
#  ('astraeus', 'male'),
#  ('jonka', 'female'),
#  ('diamante', 'female'),
#  ('maryline', 'female'),
#  ('carmelia', 'female'),
#  ('gwennan', 'female'),
#  ('amear', 'male'),
#  ('siusun', 'male'),
#  ('kaelah', 'female'),
#  ('kiyohiro', 'male'),
#  ('purvan', 'male'),
#  ('zetta', 'female'),
#  ('flay', 'male'),
#  ('nicos', 'male'),
#  ('hildred', 'female'),
#  ('makaria', 'female'),
#  ('dakarri', 'male'),
#  ('myara', 'female'),
#  ('ambri', 'female'),
#  ('utae', 'female'),
#  ('tingji', 'male'),
#  ('sylviane', 'female'),
#  ('idlia', 'female'),
#  ('lediana', 'female'),
#  ('alexandrina', 'female'),
#  ('sufiya', 'female'),
#  ('duong', 'male'),
#  ('najea', 'female'),
#  ('ehrengard', 'female'),
#  ('loan', 'male'),
#  ('kleo', 'male'),
#  ('gautier', 'male'),
#  ('zelmarie', 'female'),
#  ('aubriona', 'female'),
#  ('anamile', 'female'),
#  ('lepanto', 'male'),
#  ('analize', 'female'),
#  ('joshua', 'male'),
#  ('arlos', 'male'),
#  ('diedri', 'female'),
#  ('anique', 'female'),
#  ('jonothan', 'male'),
#  ('idalou', 'female'),
#  ('alexandia', 'female'),
#  ('jefto', 'male'),
#  ('brendyn', 'male'),
#  ('lenleonard', 'male'),
#  ('breckynn', 'female'),
#  ('cynteria', 'female'),
#  ('tangee', 'female'),
#  ('socheata', 'female'),
#  ('iselys', 'female'),
#  ('katisha', 'female'),
#  ('friedbald', 'male'),
#  ('luzetta', 'female'),
#  ('ellet', 'male'),
#  ('aybike', 'male'),
#  ('mika', 'male'),
#  ('philly', 'male'),
#  ('priansh', 'male'),
#  ('burglind', 'female'),
#  ('loria', 'female'),
#  ('lilliah', 'female'),
#  ('jilliann', 'female'),
#  ('chaviv', 'male'),
#  ('travonne', 'male'),
#  ('rhone', 'male'),
#  ('celsa', 'female'),
#  ('genadij', 'male'),
#  ('frieda', 'female'),
#  ('heraclio', 'male'),
#  ('lejuan', 'male'),
#  ('hyunwoo', 'male'),
#  ('smiljana', 'female'),
#  ('artemas', 'male'),
#  ('claira', 'female'),
#  ('audrei', 'female'),
#  ('narsiso', 'male'),
#  ('jianqun', 'male'),
#  ('detavius', 'male'),
#  ('hucksley', 'male'),
#  ('yasniel', 'male'),
#  ('racha', 'female'),
#  ('tommie', 'male'),
#  ('jash', 'male'),
#  ('alair', 'female'),
#  ('omari', 'male'),
#  ('luzmar', 'female'),
#  ('veselko', 'male'),
#  ('ninghui', 'male'),
#  ('erinmarie', 'female'),
#  ('layth', 'male'),
#  ('dulaney', 'female'),
#  ('cansever', 'female'),
#  ('onas', 'male'),
#  ('farrad', 'male'),
#  ('byungok', 'female'),
#  ('tanjyot', 'female'),
#  ('tajane', 'female'),
#  ('dzion', 'male'),
#  ('mingrui', 'male'),
#  ('iosif', 'male'),
#  ('murile', 'female'),
#  ('herwig', 'male'),
#  ('zuley', 'female'),
#  ('aley', 'female'),
#  ('anniece', 'female'),
#  ('renxiang', 'male'),
#  ('bernadette', 'female'),
#  ('anusri', 'female'),
#  ('attila', 'female'),
#  ('deyanne', 'female'),
#  ('chans', 'male'),
#  ('iolia', 'female'),
#  ('nemesis', 'female'),
#  ('itzelt', 'female'),
#  ...]

# %%
nl = namelist.copy()

# %%
random.shuffle(nl)
nl
# Out:
# [('delephine', 'female'),
#  ('kaymi', 'female'),
#  ('jayni', 'female'),
#  ('shareema', 'female'),
#  ('brandun', 'male'),
#  ('coleon', 'male'),
#  ('kemisha', 'female'),
#  ('crestina', 'female'),
#  ('kadir', 'male'),
#  ('guisel', 'female'),
#  ('meifeng', 'male'),
#  ('wilder', 'male'),
#  ('kazuyo', 'female'),
#  ('danny', 'male'),
#  ('devontra', 'male'),
#  ('aaliah', 'female'),
#  ('trevis', 'male'),
#  ('taishi', 'male'),
#  ('sigrn', 'female'),
#  ('daemen', 'male'),
#  ('huashan', 'male'),
#  ('torence', 'male'),
#  ('kenaya', 'female'),
#  ('najaah', 'female'),
#  ('katsumi', 'male'),
#  ('jionny', 'male'),
#  ('chyanne', 'female'),
#  ('kiajah', 'female'),
#  ('chasmin', 'female'),
#  ('haney', 'male'),
#  ('adesola', 'female'),
#  ('mingyue', 'male'),
#  ('shirlon', 'female'),
#  ('zaharra', 'female'),
#  ('serafine', 'female'),
#  ('shiniya', 'female'),
#  ('janiza', 'female'),
#  ('markchristopher', 'male'),
#  ('hanora', 'female'),
#  ('edwynn', 'male'),
#  ('sterie', 'male'),
#  ('kiaralee', 'female'),
#  ('suhas', 'male'),
#  ('janella', 'female'),
#  ('verne', 'male'),
#  ('aafiyah', 'female'),
#  ('zhentao', 'male'),
#  ('thurnell', 'male'),
#  ('andraia', 'female'),
#  ('judicalle', 'female'),
#  ('kaladin', 'male'),
#  ('rayelle', 'female'),
#  ('qixu', 'male'),
#  ('flavius', 'male'),
#  ('meoshi', 'female'),
#  ('xiuyan', 'male'),
#  ('klowey', 'female'),
#  ('valice', 'male'),
#  ('aleda', 'female'),
#  ('sharanakumar', 'male'),
#  ('denishia', 'female'),
#  ('jamelyn', 'female'),
#  ('efqan', 'male'),
#  ('jiangtao', 'male'),
#  ('kyshon', 'male'),
#  ('rosylin', 'female'),
#  ('jalyla', 'female'),
#  ('dejanelle', 'female'),
#  ('ledawn', 'female'),
#  ('yingjun', 'male'),
#  ('junting', 'female'),
#  ('ladonta', 'male'),
#  ('alzahra', 'female'),
#  ('eashan', 'male'),
#  ('straschko', 'male'),
#  ('selyn', 'female'),
#  ('grita', 'female'),
#  ('samanvi', 'female'),
#  ('elielisabet', 'male'),
#  ('senaya', 'female'),
#  ('emilly', 'female'),
#  ('overton', 'male'),
#  ('lylian', 'male'),
#  ('zikia', 'female'),
#  ('kimorah', 'female'),
#  ('deray', 'male'),
#  ('morrisa', 'female'),
#  ('josephene', 'female'),
#  ('mama', 'female'),
#  ('hennley', 'female'),
#  ('vicent', 'male'),
#  ('byungjin', 'male'),
#  ('keltin', 'male'),
#  ('darniece', 'female'),
#  ('guleif', 'female'),
#  ('aaryah', 'female'),
#  ('trevorjames', 'male'),
#  ('aftab', 'male'),
#  ('taressa', 'female'),
#  ('jhasir', 'male'),
#  ('janeal', 'female'),
#  ('chitina', 'female'),
#  ('lynnlee', 'female'),
#  ('ridley', 'male'),
#  ('kadi', 'female'),
#  ('jemmy', 'female'),
#  ('jessinia', 'female'),
#  ('sueko', 'female'),
#  ('jeraud', 'male'),
#  ('caityln', 'female'),
#  ('brandal', 'male'),
#  ('shankeria', 'female'),
#  ('kahleia', 'female'),
#  ('monchelle', 'female'),
#  ('dewaine', 'male'),
#  ('trevion', 'male'),
#  ('anansa', 'female'),
#  ('elsgard', 'female'),
#  ('ayala', 'female'),
#  ('lueva', 'female'),
#  ('musat', 'male'),
#  ('gilio', 'male'),
#  ('traudlinde', 'female'),
#  ('jearldine', 'female'),
#  ('yevonne', 'female'),
#  ('rasaan', 'male'),
#  ('eoline', 'female'),
#  ('ualtar', 'male'),
#  ('ahkai', 'male'),
#  ('ilyada', 'female'),
#  ('gurshaan', 'male'),
#  ('sevannah', 'female'),
#  ('efstathios', 'male'),
#  ('ezlynn', 'female'),
#  ('keetra', 'female'),
#  ('raymir', 'male'),
#  ('shurhonda', 'female'),
#  ('tovah', 'female'),
#  ('zaylynn', 'female'),
#  ('vanness', 'male'),
#  ('laylonnie', 'female'),
#  ('ugur', 'male'),
#  ('torrien', 'male'),
#  ('rashmi', 'male'),
#  ('ebanie', 'female'),
#  ('ceaser', 'male'),
#  ('haxhere', 'female'),
#  ('dafna', 'female'),
#  ('erlinda', 'female'),
#  ('akeria', 'female'),
#  ('harkeem', 'male'),
#  ('okema', 'female'),
#  ('denaly', 'female'),
#  ('sharang', 'male'),
#  ('renasia', 'female'),
#  ('divit', 'male'),
#  ('jaymarion', 'male'),
#  ('abryella', 'female'),
#  ('annunziato', 'male'),
#  ('hadly', 'female'),
#  ('abdelhamid', 'male'),
#  ('catrinia', 'female'),
#  ('healani', 'female'),
#  ('bertaberthi', 'male'),
#  ('christoopher', 'male'),
#  ('edelina', 'female'),
#  ('armele', 'female'),
#  ('rayhona', 'female'),
#  ('samaria', 'female'),
#  ('margaretta', 'female'),
#  ('ranesha', 'female'),
#  ('sevasti', 'female'),
#  ('ellexis', 'female'),
#  ('aderemi', 'male'),
#  ('hecheng', 'male'),
#  ('sharvil', 'male'),
#  ('zamirra', 'female'),
#  ('edwardjames', 'male'),
#  ('dragoje', 'male'),
#  ('weijun', 'female'),
#  ('froney', 'female'),
#  ('emalia', 'female'),
#  ('prynceton', 'male'),
#  ('thala', 'female'),
#  ('selvyn', 'male'),
#  ('taiyana', 'female'),
#  ('olliyah', 'female'),
#  ('juanjr', 'male'),
#  ('ayiana', 'female'),
#  ('raaya', 'female'),
#  ('dominisha', 'female'),
#  ('mari', 'female'),
#  ('yacov', 'male'),
#  ('kaylnn', 'female'),
#  ('miral', 'female'),
#  ('delana', 'female'),
#  ('amante', 'male'),
#  ('michalyn', 'female'),
#  ('zohe', 'female'),
#  ('kaben', 'male'),
#  ('cyriac', 'male'),
#  ('paitlynn', 'female'),
#  ('geerda', 'female'),
#  ('beunca', 'female'),
#  ('stefana', 'female'),
#  ('shrita', 'female'),
#  ('dakwan', 'male'),
#  ('digin', 'male'),
#  ('nijiah', 'female'),
#  ('shitsyr', 'female'),
#  ('faridah', 'female'),
#  ('onan', 'male'),
#  ('bassil', 'male'),
#  ('rahni', 'female'),
#  ('hizir', 'male'),
#  ('devron', 'male'),
#  ('sofijka', 'female'),
#  ('mutsunori', 'male'),
#  ('taesun', 'male'),
#  ('heijo', 'male'),
#  ('manferd', 'male'),
#  ('lyan', 'female'),
#  ('casino', 'male'),
#  ('bogoljub', 'male'),
#  ('philphilip', 'male'),
#  ('amis', 'male'),
#  ('fode', 'male'),
#  ('elinar', 'female'),
#  ('larson', 'male'),
#  ('eltje', 'male'),
#  ('halim', 'male'),
#  ('zerena', 'female'),
#  ('berj', 'male'),
#  ('hallmann', 'male'),
#  ('lisah', 'female'),
#  ('zema', 'female'),
#  ('ellawee', 'female'),
#  ('everson', 'male'),
#  ('semahat', 'female'),
#  ('deneishia', 'female'),
#  ('ewel', 'male'),
#  ('ivie', 'female'),
#  ('chance', 'male'),
#  ('ludka', 'female'),
#  ('marketa', 'female'),
#  ('zaza', 'male'),
#  ('hartford', 'male'),
#  ('zyonna', 'female'),
#  ('elani', 'female'),
#  ('merlyn', 'male'),
#  ('zaelie', 'female'),
#  ('onell', 'female'),
#  ('sherrie', 'female'),
#  ('joriann', 'female'),
#  ('jaten', 'male'),
#  ('auttum', 'female'),
#  ('hairuo', 'male'),
#  ('lesther', 'male'),
#  ('juzer', 'male'),
#  ('joyia', 'female'),
#  ('dvaughn', 'male'),
#  ('barjdeep', 'female'),
#  ('apryle', 'female'),
#  ('jaxxen', 'male'),
#  ('cashion', 'male'),
#  ('anti', 'male'),
#  ('guanshan', 'male'),
#  ('miichael', 'male'),
#  ('angelino', 'male'),
#  ('guangqiang', 'male'),
#  ('sherwin', 'male'),
#  ('izchak', 'male'),
#  ('marcal', 'male'),
#  ('kimly', 'female'),
#  ('seriana', 'female'),
#  ('juanramon', 'male'),
#  ('marisal', 'female'),
#  ('krisslyn', 'female'),
#  ('khaliyah', 'female'),
#  ('genard', 'male'),
#  ('ellianna', 'female'),
#  ('yasmean', 'female'),
#  ('anjonette', 'female'),
#  ('zariel', 'female'),
#  ('lincon', 'male'),
#  ('otes', 'male'),
#  ('kera', 'female'),
#  ('chylar', 'female'),
#  ('kijah', 'female'),
#  ('jermayne', 'male'),
#  ('gulten', 'female'),
#  ('yoli', 'female'),
#  ('shanteya', 'female'),
#  ('argyroula', 'female'),
#  ('dominque', 'female'),
#  ('jannine', 'female'),
#  ('monyette', 'female'),
#  ('francenia', 'female'),
#  ('camdynn', 'female'),
#  ('tareyn', 'female'),
#  ('alyre', 'male'),
#  ('dalijah', 'female'),
#  ('igone', 'female'),
#  ('shoichiro', 'male'),
#  ('diavion', 'female'),
#  ('mariecarmel', 'female'),
#  ('dequita', 'female'),
#  ('dako', 'male'),
#  ('zyon', 'male'),
#  ('caliel', 'male'),
#  ('nadezhda', 'female'),
#  ('kirjak', 'male'),
#  ('desani', 'female'),
#  ('kishore', 'male'),
#  ('tanaya', 'female'),
#  ('dominae', 'female'),
#  ('burie', 'male'),
#  ('elidet', 'female'),
#  ('metella', 'female'),
#  ('huijian', 'male'),
#  ('leliana', 'female'),
#  ('blinda', 'female'),
#  ('siro', 'male'),
#  ('searia', 'female'),
#  ('mikiela', 'female'),
#  ('eitelfritz', 'male'),
#  ('aayanah', 'female'),
#  ('krisna', 'female'),
#  ('jerica', 'female'),
#  ('qingchang', 'male'),
#  ('destinyann', 'female'),
#  ('carland', 'male'),
#  ('saniiyah', 'female'),
#  ('jozijna', 'female'),
#  ('syrah', 'female'),
#  ('padon', 'male'),
#  ('rayvyn', 'female'),
#  ('erna', 'female'),
#  ('carisia', 'female'),
#  ('alynnah', 'female'),
#  ('xachary', 'male'),
#  ('mridula', 'female'),
#  ('jailynne', 'female'),
#  ('yedda', 'female'),
#  ('akshai', 'male'),
#  ('bilel', 'male'),
#  ('eleina', 'female'),
#  ('mahlah', 'female'),
#  ('lute', 'male'),
#  ('atuf', 'male'),
#  ('snjlfur', 'male'),
#  ('paison', 'female'),
#  ('gianbattista', 'male'),
#  ('damacio', 'male'),
#  ('malec', 'male'),
#  ('zakhar', 'male'),
#  ('thanvi', 'female'),
#  ('kakisha', 'female'),
#  ('delcia', 'female'),
#  ('khori', 'female'),
#  ('shaaliyah', 'female'),
#  ('gerardette', 'female'),
#  ('idalys', 'female'),
#  ('glhanim', 'female'),
#  ('chanceler', 'male'),
#  ('debdeborah', 'male'),
#  ('terase', 'female'),
#  ('keishun', 'male'),
#  ('niina', 'female'),
#  ('vidunas', 'male'),
#  ('tomoo', 'female'),
#  ('zackari', 'male'),
#  ('sebastain', 'male'),
#  ('calysta', 'female'),
#  ('khyleigh', 'female'),
#  ('rodge', 'male'),
#  ('hadija', 'female'),
#  ('sushila', 'female'),
#  ('guoqin', 'male'),
#  ('ayvee', 'female'),
#  ('rens', 'male'),
#  ('frej', 'male'),
#  ('leathy', 'female'),
#  ('samtha', 'female'),
#  ('gerlofke', 'female'),
#  ('mardine', 'female'),
#  ('cyrilla', 'female'),
#  ('androw', 'male'),
#  ('aarohan', 'male'),
#  ('yosseline', 'female'),
#  ('zayda', 'female'),
#  ('rondallyn', 'female'),
#  ('niti', 'female'),
#  ('margena', 'female'),
#  ('miloslava', 'female'),
#  ('zafeiria', 'female'),
#  ('finnegan', 'male'),
#  ('imantas', 'male'),
#  ('luboslava', 'female'),
#  ('welles', 'male'),
#  ('lonore', 'female'),
#  ('makynzee', 'female'),
#  ('markeyda', 'female'),
#  ('tuomo', 'male'),
#  ('janiah', 'female'),
#  ('hamit', 'male'),
#  ('kadarian', 'male'),
#  ('chantele', 'female'),
#  ('tiajah', 'female'),
#  ('haegen', 'male'),
#  ('euisuk', 'male'),
#  ('verinica', 'female'),
#  ('olgierd', 'male'),
#  ('shemeca', 'female'),
#  ('erickson', 'male'),
#  ('medhini', 'female'),
#  ('breonna', 'female'),
#  ('hurrem', 'female'),
#  ('kalianne', 'female'),
#  ('corneliea', 'female'),
#  ('kaeon', 'male'),
#  ('wenzhao', 'male'),
#  ('gredel', 'female'),
#  ('burlene', 'female'),
#  ('urvashi', 'female'),
#  ('katena', 'female'),
#  ('sufang', 'male'),
#  ('avonne', 'female'),
#  ('kadetra', 'female'),
#  ('ainash', 'female'),
#  ('carolyn', 'male'),
#  ('yaleiza', 'female'),
#  ('erniest', 'male'),
#  ('karlito', 'male'),
#  ('khup', 'male'),
#  ('youngkil', 'male'),
#  ('jazzma', 'female'),
#  ('molli', 'female'),
#  ('pasco', 'male'),
#  ('zhaochun', 'male'),
#  ('dehua', 'male'),
#  ('victorianna', 'female'),
#  ('naqeeb', 'male'),
#  ('qianxun', 'male'),
#  ('crit', 'male'),
#  ('jordie', 'male'),
#  ('naporsha', 'female'),
#  ('shubing', 'male'),
#  ('timothea', 'female'),
#  ('shadiamon', 'female'),
#  ('emmarie', 'female'),
#  ('kulyu', 'male'),
#  ('phedra', 'female'),
#  ('qinfang', 'male'),
#  ('goldean', 'female'),
#  ('nekeya', 'female'),
#  ('annick', 'female'),
#  ('vilayat', 'male'),
#  ('zehava', 'female'),
#  ('florestan', 'male'),
#  ('mayo', 'female'),
#  ('ermanno', 'male'),
#  ('caldonia', 'female'),
#  ('aniyha', 'female'),
#  ('claiborn', 'male'),
#  ('onute', 'female'),
#  ('nedra', 'female'),
#  ('herson', 'male'),
#  ('leinani', 'female'),
#  ('issaic', 'male'),
#  ('amarpreet', 'female'),
#  ('dewitte', 'male'),
#  ('cuilan', 'male'),
#  ('yongsan', 'male'),
#  ('dzana', 'female'),
#  ('airielle', 'female'),
#  ('talajha', 'female'),
#  ('aubriauna', 'female'),
#  ('audranna', 'female'),
#  ('doneisha', 'female'),
#  ('takashia', 'female'),
#  ('mckena', 'female'),
#  ('sabriye', 'female'),
#  ('daneila', 'female'),
#  ('javius', 'male'),
#  ('olgie', 'female'),
#  ('marje', 'female'),
#  ('kalvin', 'male'),
#  ('radomra', 'female'),
#  ('chevonda', 'female'),
#  ('kwan', 'male'),
#  ('chaddrick', 'male'),
#  ('diran', 'male'),
#  ('synclair', 'female'),
#  ('eulalio', 'male'),
#  ('kamaree', 'male'),
#  ('kniyah', 'female'),
#  ('elijha', 'male'),
#  ('yustin', 'male'),
#  ('izan', 'male'),
#  ('kassiani', 'female'),
#  ('jamene', 'female'),
#  ('ulviyye', 'female'),
#  ('beesan', 'female'),
#  ('montrel', 'male'),
#  ('mandhir', 'male'),
#  ('oluwatimilehin', 'male'),
#  ('vikis', 'male'),
#  ('tingfung', 'male'),
#  ('genadij', 'male'),
#  ('akimi', 'female'),
#  ('mellyssa', 'female'),
#  ('dervla', 'female'),
#  ('aniken', 'male'),
#  ('sheanna', 'female'),
#  ('leonette', 'female'),
#  ('chyrel', 'female'),
#  ('shanikque', 'female'),
#  ('miladie', 'female'),
#  ('romelda', 'female'),
#  ('simya', 'female'),
#  ('keyonne', 'male'),
#  ('itsuko', 'female'),
#  ('xiutao', 'male'),
#  ('denyce', 'female'),
#  ('minisha', 'female'),
#  ('shanthi', 'female'),
#  ('anitza', 'female'),
#  ('meital', 'female'),
#  ('mijah', 'female'),
#  ('marcita', 'female'),
#  ('deriana', 'female'),
#  ('doron', 'male'),
#  ('maoz', 'male'),
#  ('ethridge', 'male'),
#  ('brandisha', 'female'),
#  ('meldra', 'female'),
#  ('yalina', 'female'),
#  ('meihong', 'male'),
#  ('harneet', 'female'),
#  ('tyresse', 'male'),
#  ('mania', 'female'),
#  ('tiereny', 'female'),
#  ('dvyne', 'female'),
#  ('trillium', 'female'),
#  ('rashied', 'male'),
#  ('colonel', 'male'),
#  ('vj', 'female'),
#  ('diyana', 'female'),
#  ('alyda', 'female'),
#  ('tamye', 'female'),
#  ('airionna', 'female'),
#  ('yns', 'female'),
#  ('stephaun', 'male'),
#  ('jianchu', 'male'),
#  ('kavina', 'female'),
#  ('magnola', 'female'),
#  ('krustina', 'female'),
#  ('jujhar', 'male'),
#  ('adalaide', 'female'),
#  ('jamye', 'female'),
#  ('ezel', 'male'),
#  ('shaida', 'female'),
#  ('nodirbek', 'male'),
#  ('sarika', 'female'),
#  ('svtlushe', 'female'),
#  ('zhuldyz', 'female'),
#  ('vasilia', 'female'),
#  ('sime', 'male'),
#  ('iek', 'female'),
#  ('zerita', 'female'),
#  ('mumtaz', 'male'),
#  ('ingunn', 'female'),
#  ('hewan', 'female'),
#  ('vreneli', 'female'),
#  ('shelana', 'female'),
#  ('mevser', 'female'),
#  ('gabrian', 'male'),
#  ('jerryjeremiah', 'male'),
#  ('infinity', 'female'),
#  ('zheko', 'male'),
#  ('mustaf', 'male'),
#  ('dawndria', 'female'),
#  ('brennick', 'male'),
#  ('yesh', 'male'),
#  ('adielle', 'female'),
#  ('taiyin', 'male'),
#  ('chaena', 'female'),
#  ('jianbing', 'male'),
#  ('brianni', 'female'),
#  ('brigido', 'male'),
#  ('larnette', 'female'),
#  ('meiyu', 'male'),
#  ('vannina', 'female'),
#  ('terrissa', 'female'),
#  ('umbro', 'male'),
#  ('panagiotes', 'male'),
#  ('claranell', 'female'),
#  ('cyprian', 'male'),
#  ('donaciano', 'male'),
#  ('troylynn', 'female'),
#  ('daghan', 'male'),
#  ('bridge', 'male'),
#  ('xiudong', 'male'),
#  ('adalisse', 'female'),
#  ('foy', 'male'),
#  ('joyice', 'female'),
#  ('aliana', 'female'),
#  ('wande', 'male'),
#  ('latricia', 'female'),
#  ('isaac', 'male'),
#  ('engelhard', 'male'),
#  ('guangen', 'male'),
#  ('kirtley', 'male'),
#  ('naeem', 'male'),
#  ('lometa', 'female'),
#  ('louvonia', 'female'),
#  ('guitang', 'male'),
#  ('jocelin', 'female'),
#  ('yaozu', 'male'),
#  ('cheick', 'male'),
#  ('bektash', 'male'),
#  ('huixin', 'male'),
#  ('clairece', 'female'),
#  ('mahmure', 'female'),
#  ('timani', 'female'),
#  ('loriah', 'female'),
#  ('marisella', 'female'),
#  ('mahkiya', 'female'),
#  ('deral', 'male'),
#  ('charil', 'female'),
#  ('breze', 'female'),
#  ('taifa', 'female'),
#  ('naoki', 'male'),
#  ('cailee', 'female'),
#  ('katre', 'female'),
#  ('rielle', 'female'),
#  ('norair', 'male'),
#  ('amaka', 'female'),
#  ('qifa', 'male'),
#  ('taiyanna', 'female'),
#  ('shiley', 'female'),
#  ('nilay', 'male'),
#  ('elek', 'male'),
#  ('mandisha', 'female'),
#  ('keyrra', 'female'),
#  ('davionna', 'female'),
#  ('jorrik', 'male'),
#  ('dakoata', 'male'),
#  ('shimeek', 'male'),
#  ('colmon', 'male'),
#  ('shannen', 'female'),
#  ('sonka', 'female'),
#  ('taizley', 'female'),
#  ('amariah', 'female'),
#  ('swain', 'male'),
#  ('javiah', 'female'),
#  ('mayreli', 'female'),
#  ('jerrelle', 'male'),
#  ('swecha', 'female'),
#  ('chatavia', 'female'),
#  ('henritta', 'female'),
#  ('fjorela', 'female'),
#  ('mackinzie', 'female'),
#  ('teddie', 'male'),
#  ('xiongping', 'male'),
#  ('calhan', 'male'),
#  ('wengang', 'male'),
#  ('keyala', 'female'),
#  ('ottmar', 'male'),
#  ('juline', 'female'),
#  ('fionnuala', 'female'),
#  ('zhenni', 'male'),
#  ('esmail', 'male'),
#  ('selen', 'female'),
#  ('nachaly', 'female'),
#  ('ronnal', 'male'),
#  ('armel', 'male'),
#  ('ingibjartur', 'male'),
#  ('phelicia', 'female'),
#  ('jory', 'male'),
#  ('hongjie', 'male'),
#  ('johnnice', 'female'),
#  ('mihyang', 'female'),
#  ('jerrie', 'male'),
#  ('gwendy', 'female'),
#  ('hernni', 'male'),
#  ('myrlene', 'female'),
#  ('niyona', 'female'),
#  ('tydarian', 'male'),
#  ('charnissa', 'female'),
#  ('jancee', 'female'),
#  ('jakerion', 'male'),
#  ('curtistine', 'female'),
#  ('gauvain', 'male'),
#  ('dennys', 'male'),
#  ('ninja', 'female'),
#  ('ubbe', 'male'),
#  ('yuan', 'female'),
#  ('waelynn', 'female'),
#  ('terece', 'female'),
#  ('wasim', 'male'),
#  ('jia', 'female'),
#  ('luster', 'male'),
#  ('wilfred', 'male'),
#  ('chelle', 'female'),
#  ('zdemir', 'male'),
#  ('casi', 'female'),
#  ('kawaski', 'male'),
#  ('ineza', 'female'),
#  ('syeira', 'female'),
#  ('casarah', 'female'),
#  ('shariana', 'female'),
#  ('karapet', 'male'),
#  ('yanlian', 'male'),
#  ('effi', 'female'),
#  ('tanyiah', 'female'),
#  ('lawaia', 'male'),
#  ('chauna', 'female'),
#  ('shellee', 'female'),
#  ('bojcho', 'male'),
#  ('zhongyan', 'male'),
#  ('petrice', 'female'),
#  ('breighton', 'male'),
#  ('ragbir', 'male'),
#  ('tzipa', 'female'),
#  ('innocenzo', 'male'),
#  ('gloryvee', 'female'),
#  ('shamaar', 'male'),
#  ('moreland', 'male'),
#  ('anneclaire', 'female'),
#  ('feipeng', 'male'),
#  ('meilute', 'female'),
#  ('nikka', 'female'),
#  ('kashmiere', 'female'),
#  ('arismel', 'female'),
#  ('chiyu', 'male'),
#  ('berrin', 'female'),
#  ('keshira', 'female'),
#  ('graye', 'female'),
#  ('zaroon', 'male'),
#  ('ryen', 'male'),
#  ('dzianis', 'male'),
#  ('bracyn', 'male'),
#  ('mikel', 'male'),
#  ('schwanhild', 'female'),
#  ('deisi', 'female'),
#  ('janey', 'female'),
#  ('lailey', 'female'),
#  ('mauricia', 'female'),
#  ('ottkar', 'male'),
#  ('nevim', 'female'),
#  ('isamarie', 'female'),
#  ('manard', 'male'),
#  ('ajena', 'female'),
#  ('manna', 'male'),
#  ('rowen', 'male'),
#  ('dinnia', 'female'),
#  ('aevah', 'female'),
#  ('shazeb', 'male'),
#  ('troyu', 'male'),
#  ('srikruthi', 'female'),
#  ('kinisha', 'female'),
#  ('xin', 'male'),
#  ('bonnielou', 'female'),
#  ('cleotis', 'male'),
#  ('manilo', 'male'),
#  ('fletch', 'male'),
#  ('yitzhak', 'male'),
#  ('angeliene', 'female'),
#  ('cooley', 'male'),
#  ('deldra', 'female'),
#  ('danese', 'female'),
#  ('ishtiyaq', 'male'),
#  ('nancyd', 'female'),
#  ('huina', 'male'),
#  ('zakira', 'female'),
#  ('jinheng', 'male'),
#  ('joplyn', 'female'),
#  ('maxfield', 'male'),
#  ('jalesse', 'female'),
#  ('arooj', 'female'),
#  ('shelbyjean', 'female'),
#  ('scolastica', 'female'),
#  ('chie', 'female'),
#  ('katiann', 'female'),
#  ('elfielfriede', 'male'),
#  ('kaoir', 'female'),
#  ('louwana', 'female'),
#  ('oktam', 'male'),
#  ('mersed', 'male'),
#  ('zayriah', 'female'),
#  ('allec', 'male'),
#  ('yuma', 'female'),
#  ('rucker', 'male'),
#  ('rutu', 'female'),
#  ('atdhe', 'male'),
#  ('lizzie', 'female'),
#  ('kamrin', 'male'),
#  ('kayzen', 'male'),
#  ('elneda', 'female'),
#  ('lakysha', 'female'),
#  ('franisco', 'male'),
#  ('xilong', 'male'),
#  ('baljit', 'male'),
#  ('mohamadali', 'male'),
#  ('masayasu', 'male'),
#  ('zhaire', 'male'),
#  ('bingxin', 'male'),
#  ('terreka', 'female'),
#  ('flixa', 'female'),
#  ('ionelia', 'female'),
#  ('eden', 'female'),
#  ('rexhep', 'male'),
#  ('clodagh', 'female'),
#  ('derquan', 'male'),
#  ('aashana', 'female'),
#  ('chastin', 'male'),
#  ('varonica', 'female'),
#  ('keyiana', 'female'),
#  ('laiden', 'male'),
#  ('qusai', 'male'),
#  ('kimkimberley', 'male'),
#  ('shovan', 'female'),
#  ('ishea', 'female'),
#  ('kenzel', 'male'),
#  ('reginauld', 'male'),
#  ('lensy', 'male'),
#  ('chequita', 'female'),
#  ('tefa', 'female'),
#  ('fredine', 'female'),
#  ('caaliyah', 'female'),
#  ('terz', 'female'),
#  ('park', 'male'),
#  ('nikaila', 'female'),
#  ('latonza', 'female'),
#  ('asmaa', 'female'),
#  ('shaquay', 'female'),
#  ('linville', 'male'),
#  ('jhavier', 'male'),
#  ('merlot', 'female'),
#  ('venetka', 'female'),
#  ('carmeshia', 'female'),
#  ('din', 'male'),
#  ('boguslaw', 'male'),
#  ('aadhavan', 'male'),
#  ('vienna', 'female'),
#  ('zongshan', 'male'),
#  ('marietje', 'female'),
#  ('teanisha', 'female'),
#  ('rosea', 'female'),
#  ('sile', 'male'),
#  ('roniesha', 'female'),
#  ('velida', 'female'),
#  ('lepido', 'male'),
#  ('dazsha', 'female'),
#  ('hyson', 'male'),
#  ('iselis', 'female'),
#  ('luned', 'female'),
#  ('linxiang', 'male'),
#  ('weiland', 'male'),
#  ('waldtraut', 'female'),
#  ('zerina', 'female'),
#  ('annebrbel', 'female'),
#  ('gerhardus', 'male'),
#  ('homeira', 'female'),
#  ('dallys', 'female'),
#  ('paolo', 'male'),
#  ('kaymin', 'female'),
#  ('lerae', 'female'),
#  ('egbert', 'male'),
#  ('ameenah', 'female'),
#  ('kaimani', 'male'),
#  ('fengqun', 'male'),
#  ('asjha', 'female'),
#  ('visar', 'male'),
#  ('rumenitchka', 'female'),
#  ('celle', 'female'),
#  ('lizelle', 'female'),
#  ('maart', 'male'),
#  ('diletto', 'male'),
#  ('demitrie', 'male'),
#  ('shawntae', 'female'),
#  ('qiyun', 'male'),
#  ('jalun', 'male'),
#  ('jomana', 'female'),
#  ('keecha', 'female'),
#  ('calasia', 'female'),
#  ('hidenao', 'male'),
#  ('yunpeng', 'male'),
#  ('atyanna', 'female'),
#  ('jezelle', 'female'),
#  ('mahaliah', 'female'),
#  ('anette', 'female'),
#  ('ayomikun', 'male'),
#  ('arlyss', 'female'),
#  ('dunwei', 'male'),
#  ('sherrol', 'female'),
#  ('bakyt', 'male'),
#  ('teionna', 'female'),
#  ('yongge', 'male'),
#  ('thamia', 'female'),
#  ('freesia', 'female'),
#  ('lakeysa', 'female'),
#  ('brenia', 'female'),
#  ('aliahna', 'female'),
#  ('ridha', 'male'),
#  ('demetirus', 'male'),
#  ('josht', 'male'),
#  ('baziliu', 'male'),
#  ('khadesha', 'female'),
#  ('zubing', 'male'),
#  ('aviara', 'female'),
#  ('pacita', 'female'),
#  ('aydriana', 'female'),
#  ('ilqar', 'male'),
#  ('jishan', 'male'),
#  ('seras', 'female'),
#  ('irha', 'female'),
#  ('iustin', 'male'),
#  ('zuhdo', 'male'),
#  ('daviel', 'male'),
#  ('whitnye', 'female'),
#  ('augus', 'male'),
#  ('alondrea', 'female'),
#  ('petrona', 'female'),
#  ('essam', 'male'),
#  ('remini', 'female'),
#  ('audria', 'female'),
#  ('frances', 'female'),
#  ('rodolpho', 'male'),
#  ('denasha', 'female'),
#  ('laterra', 'female'),
#  ('mihaiu', 'male'),
#  ('dequentin', 'male'),
#  ('zonglin', 'male'),
#  ('delford', 'male'),
#  ('eshal', 'female'),
#  ('graceanne', 'female'),
#  ('maiyah', 'female'),
#  ('quennel', 'male'),
#  ('dorisa', 'female'),
#  ('eliene', 'female'),
#  ('pratap', 'male'),
#  ('anaejah', 'female'),
#  ('maximiliano', 'male'),
#  ('shoira', 'female'),
#  ('seniya', 'female'),
#  ('wingolf', 'male'),
#  ('rodericka', 'female'),
#  ('mckinely', 'male'),
#  ('hongdi', 'male'),
#  ('kaedynce', 'female'),
#  ('leondrus', 'male'),
#  ('envyi', 'female'),
#  ('floetta', 'female'),
#  ('boguslawa', 'female'),
#  ('yatzil', 'female'),
#  ('kamarrion', 'male'),
#  ('charlton', 'male'),
#  ('sione', 'male'),
#  ('shewaye', 'female'),
#  ('redge', 'male'),
#  ('garvie', 'male'),
#  ('tatsyana', 'female'),
#  ('jaylynn', 'female'),
#  ('emilse', 'female'),
#  ('maxyn', 'male'),
#  ('yovanna', 'female'),
#  ('hueyjen', 'female'),
#  ('calixto', 'male'),
#  ('qihan', 'male'),
#  ('raimundo', 'male'),
#  ('wilhelmina', 'female'),
#  ('dawuan', 'male'),
#  ('akeiba', 'female'),
#  ('yaniah', 'female'),
#  ('tawfeeq', 'male'),
#  ('geretha', 'female'),
#  ('mykena', 'female'),
#  ('kaleiya', 'female'),
#  ('xzayvian', 'male'),
#  ('einara', 'female'),
#  ('solita', 'female'),
#  ('hyden', 'male'),
#  ('suhayr', 'female'),
#  ('theckla', 'female'),
#  ('erionne', 'female'),
#  ('romuald', 'male'),
#  ('maksims', 'male'),
#  ('stojche', 'male'),
#  ('vear', 'female'),
#  ('meris', 'female'),
#  ('guoxun', 'male'),
#  ('wake', 'male'),
#  ('krithin', 'male'),
#  ('marmaduke', 'male'),
#  ('tiefu', 'male'),
#  ('trishika', 'female'),
#  ('quellie', 'female'),
#  ...]

# %%
namelist
# Out:
# [('deshard', 'male'),
#  ('lavette', 'female'),
#  ('kaifeng', 'male'),
#  ('chidubem', 'male'),
#  ('bladyn', 'male'),
#  ('shixiong', 'male'),
#  ('juliett', 'female'),
#  ('prabhakar', 'male'),
#  ('birglinde', 'female'),
#  ('dagrunn', 'female'),
#  ('danett', 'female'),
#  ('autumn', 'female'),
#  ('chongda', 'male'),
#  ('inhong', 'male'),
#  ('roiann', 'female'),
#  ('jacyion', 'male'),
#  ('benisha', 'female'),
#  ('juliannah', 'female'),
#  ('jurinus', 'male'),
#  ('rondald', 'male'),
#  ('chalia', 'female'),
#  ('brune', 'female'),
#  ('alara', 'female'),
#  ('lasharon', 'female'),
#  ('elliekate', 'female'),
#  ('mik', 'male'),
#  ('vigneswaran', 'male'),
#  ('geneal', 'female'),
#  ('ayden', 'male'),
#  ('liwei', 'male'),
#  ('elisjah', 'male'),
#  ('aayana', 'female'),
#  ('lourdez', 'female'),
#  ('leartis', 'male'),
#  ('mogens', 'male'),
#  ('dalayah', 'female'),
#  ('chantry', 'male'),
#  ('finnborg', 'female'),
#  ('nedaa', 'female'),
#  ('johannes', 'male'),
#  ('yuleni', 'female'),
#  ('likang', 'male'),
#  ('vivvian', 'female'),
#  ('sung', 'male'),
#  ('emileigh', 'female'),
#  ('sellapah', 'male'),
#  ('janenna', 'female'),
#  ('aizhan', 'female'),
#  ('tauriel', 'female'),
#  ('hidajeta', 'female'),
#  ('dan', 'male'),
#  ('antrone', 'male'),
#  ('lilllie', 'female'),
#  ('keymi', 'female'),
#  ('bb', 'male'),
#  ('saedie', 'female'),
#  ('evalena', 'female'),
#  ('shanqual', 'female'),
#  ('shalice', 'female'),
#  ('nayden', 'male'),
#  ('helidon', 'male'),
#  ('will', 'male'),
#  ('cin', 'male'),
#  ('demple', 'female'),
#  ('mechthilde', 'female'),
#  ('rongjia', 'male'),
#  ('dierra', 'female'),
#  ('tildi', 'female'),
#  ('mikita', 'female'),
#  ('telana', 'female'),
#  ('sojin', 'female'),
#  ('kairong', 'male'),
#  ('tennica', 'female'),
#  ('orothy', 'female'),
#  ('joplynn', 'female'),
#  ('selby', 'female'),
#  ('biagia', 'female'),
#  ('slbjrt', 'female'),
#  ('jalynne', 'female'),
#  ('mendel', 'male'),
#  ('shane', 'male'),
#  ('ballard', 'male'),
#  ('ethne', 'female'),
#  ('otelinda', 'female'),
#  ('avya', 'female'),
#  ('landri', 'female'),
#  ('chelsa', 'female'),
#  ('vaune', 'female'),
#  ('ninuccia', 'female'),
#  ('yehya', 'male'),
#  ('airlene', 'female'),
#  ('dezani', 'female'),
#  ('adrianno', 'male'),
#  ('svanlaug', 'female'),
#  ('fengmei', 'male'),
#  ('nertie', 'female'),
#  ('yavier', 'male'),
#  ('aleksanteri', 'male'),
#  ('gulea', 'female'),
#  ('arnar', 'male'),
#  ('firdevs', 'female'),
#  ('sabrena', 'female'),
#  ('anindo', 'male'),
#  ('ceandra', 'female'),
#  ('clive', 'male'),
#  ('camely', 'female'),
#  ('yushuang', 'male'),
#  ('maftei', 'male'),
#  ('miranta', 'female'),
#  ('deresa', 'female'),
#  ('frimet', 'female'),
#  ('jadeah', 'female'),
#  ('adesire', 'female'),
#  ('austan', 'male'),
#  ('ryana', 'female'),
#  ('karliyah', 'female'),
#  ('rhun', 'male'),
#  ('gerco', 'male'),
#  ('ermelinda', 'female'),
#  ('zmrt', 'female'),
#  ('charetta', 'female'),
#  ('laisvunas', 'male'),
#  ('lavy', 'female'),
#  ('ilyssa', 'female'),
#  ('girdie', 'female'),
#  ('shinae', 'female'),
#  ('dyshon', 'male'),
#  ('erickia', 'female'),
#  ('jetzael', 'male'),
#  ('jayce', 'male'),
#  ('thisbe', 'female'),
#  ('cadance', 'female'),
#  ('chic', 'male'),
#  ('nahki', 'male'),
#  ('kaj', 'male'),
#  ('katrinka', 'female'),
#  ('danovan', 'male'),
#  ('johnai', 'female'),
#  ('bhawan', 'male'),
#  ('evoleht', 'female'),
#  ('lucymae', 'female'),
#  ('nevyana', 'female'),
#  ('aichun', 'male'),
#  ('charin', 'female'),
#  ('aravinthan', 'male'),
#  ('algimanta', 'female'),
#  ('rosa', 'male'),
#  ('sukil', 'male'),
#  ('valeria', 'female'),
#  ('amaurie', 'male'),
#  ('meirav', 'female'),
#  ('desra', 'female'),
#  ('wanxiang', 'male'),
#  ('secondino', 'male'),
#  ('jeancarlo', 'male'),
#  ('gon', 'male'),
#  ('dzhenka', 'female'),
#  ('qihua', 'male'),
#  ('batya', 'female'),
#  ('rezearta', 'female'),
#  ('daxon', 'male'),
#  ('marietheres', 'female'),
#  ('evamae', 'female'),
#  ('yansong', 'male'),
#  ('krimson', 'female'),
#  ('kohlton', 'male'),
#  ('lindee', 'female'),
#  ('makensley', 'female'),
#  ('charli', 'female'),
#  ('zaixin', 'male'),
#  ('analiesa', 'female'),
#  ('marjeta', 'female'),
#  ('takeyuki', 'female'),
#  ('jenese', 'female'),
#  ('branimira', 'female'),
#  ('darik', 'male'),
#  ('odina', 'female'),
#  ('emzley', 'female'),
#  ('benjamen', 'male'),
#  ('deija', 'female'),
#  ('diomid', 'male'),
#  ('parisina', 'female'),
#  ('yamia', 'female'),
#  ('sedelia', 'female'),
#  ('efe', 'male'),
#  ('tenae', 'female'),
#  ('montasia', 'female'),
#  ('haliegh', 'female'),
#  ('helmuts', 'male'),
#  ('gertie', 'female'),
#  ('clotiel', 'female'),
#  ('atte', 'male'),
#  ('lolamae', 'female'),
#  ('mareah', 'female'),
#  ('huishan', 'male'),
#  ('mingsheng', 'male'),
#  ('wendoly', 'female'),
#  ('jartavious', 'male'),
#  ('kavanaugh', 'male'),
#  ('rufino', 'male'),
#  ('mabli', 'female'),
#  ('lulah', 'female'),
#  ('shunguo', 'male'),
#  ('xiaobin', 'male'),
#  ('ivyrose', 'female'),
#  ('tanganika', 'female'),
#  ('zadquiel', 'male'),
#  ('mateushas', 'male'),
#  ('taron', 'male'),
#  ('aydeliz', 'female'),
#  ('ayriauna', 'female'),
#  ('kimlee', 'female'),
#  ('beaulah', 'female'),
#  ('clerissa', 'female'),
#  ('gogi', 'male'),
#  ('saladine', 'male'),
#  ('kiska', 'female'),
#  ('nayvia', 'female'),
#  ('santangelo', 'male'),
#  ('staten', 'male'),
#  ('vidolina', 'female'),
#  ('ashauntee', 'female'),
#  ('jaisyn', 'male'),
#  ('exavion', 'male'),
#  ('alexandrya', 'female'),
#  ('kleomenis', 'male'),
#  ('tevfik', 'male'),
#  ('demetrise', 'female'),
#  ('identas', 'male'),
#  ('maksat', 'male'),
#  ('bolan', 'male'),
#  ('shellyann', 'female'),
#  ('booja', 'female'),
#  ('tnde', 'female'),
#  ('hongzhe', 'male'),
#  ('kiniya', 'female'),
#  ('quamine', 'male'),
#  ('erdfried', 'male'),
#  ('jermarius', 'male'),
#  ('reble', 'female'),
#  ('anning', 'male'),
#  ('yorleni', 'female'),
#  ('mercedi', 'female'),
#  ('yirmeyah', 'male'),
#  ('gwen', 'female'),
#  ('arnissa', 'female'),
#  ('terianne', 'female'),
#  ('danyra', 'female'),
#  ('iqbal', 'male'),
#  ('anestis', 'male'),
#  ('arielah', 'female'),
#  ('ethelyne', 'female'),
#  ('bekah', 'female'),
#  ('lynnise', 'female'),
#  ('libra', 'female'),
#  ('katriona', 'female'),
#  ('marquietta', 'female'),
#  ('gubjrg', 'female'),
#  ('destinea', 'female'),
#  ('dodu', 'male'),
#  ('taneshia', 'female'),
#  ('adarien', 'male'),
#  ('everwien', 'male'),
#  ('yanaki', 'male'),
#  ('burley', 'male'),
#  ('ronea', 'female'),
#  ('avali', 'female'),
#  ('jontrell', 'male'),
#  ('mahrukh', 'female'),
#  ('maydene', 'female'),
#  ('kaleigh', 'female'),
#  ('lataura', 'female'),
#  ('erianne', 'female'),
#  ('kurtiss', 'male'),
#  ('meidong', 'male'),
#  ('berengario', 'male'),
#  ('jerroll', 'male'),
#  ('perseis', 'female'),
#  ('ryelee', 'female'),
#  ('viorela', 'female'),
#  ('iolanthe', 'female'),
#  ('jannina', 'female'),
#  ('trescha', 'female'),
#  ('merva', 'female'),
#  ('ilya', 'male'),
#  ('lanica', 'female'),
#  ('meichun', 'male'),
#  ('rosezina', 'female'),
#  ('magaret', 'female'),
#  ('sahas', 'male'),
#  ('laterrion', 'male'),
#  ('ashunta', 'female'),
#  ('meelis', 'male'),
#  ('vladislava', 'female'),
#  ('vernitta', 'female'),
#  ('dennese', 'female'),
#  ('jermany', 'female'),
#  ('meyanna', 'female'),
#  ('dorette', 'female'),
#  ('xulio', 'male'),
#  ('jeanessa', 'female'),
#  ('teagann', 'female'),
#  ('ilana', 'female'),
#  ('dongya', 'male'),
#  ('marliana', 'female'),
#  ('leesa', 'female'),
#  ('jesusa', 'female'),
#  ('petunia', 'female'),
#  ('rasheda', 'female'),
#  ('wyvonna', 'female'),
#  ('lajuan', 'male'),
#  ('lusetta', 'female'),
#  ('traveion', 'male'),
#  ('beiqing', 'male'),
#  ('tiniya', 'female'),
#  ('dasi', 'female'),
#  ('anicka', 'female'),
#  ('sahory', 'female'),
#  ('sukla', 'male'),
#  ('josilynn', 'female'),
#  ('yexalen', 'female'),
#  ('kloud', 'male'),
#  ('sason', 'male'),
#  ('jayleon', 'male'),
#  ('ezias', 'male'),
#  ('habbe', 'male'),
#  ('aoife', 'female'),
#  ('duwaine', 'male'),
#  ('darenda', 'female'),
#  ('zhenya', 'male'),
#  ('teresia', 'female'),
#  ('dart', 'male'),
#  ('sesselja', 'female'),
#  ('gedaliahu', 'male'),
#  ('saritha', 'female'),
#  ('adlar', 'male'),
#  ('steadman', 'male'),
#  ('genay', 'male'),
#  ('katikatalin', 'male'),
#  ('jaquandre', 'male'),
#  ('evagrace', 'female'),
#  ('kosten', 'male'),
#  ('prothit', 'male'),
#  ('adriunna', 'female'),
#  ('tomka', 'female'),
#  ('nikiesha', 'female'),
#  ('antonasia', 'female'),
#  ('wenfeng', 'male'),
#  ('annice', 'female'),
#  ('fujian', 'male'),
#  ('yvelyne', 'female'),
#  ('sathiyaseelan', 'male'),
#  ('riyako', 'female'),
#  ('jerol', 'male'),
#  ('anyely', 'female'),
#  ('lameria', 'female'),
#  ('jacobus', 'male'),
#  ('peer', 'male'),
#  ('stanton', 'male'),
#  ('mylashia', 'female'),
#  ('sadulla', 'male'),
#  ('bogomila', 'female'),
#  ('umid', 'male'),
#  ('floice', 'female'),
#  ('lbba', 'female'),
#  ('elies', 'male'),
#  ('chenia', 'female'),
#  ('danyaal', 'male'),
#  ('xiumin', 'male'),
#  ('mahani', 'female'),
#  ('myrielle', 'female'),
#  ('magalene', 'female'),
#  ('sulynn', 'female'),
#  ('wilmor', 'male'),
#  ('iole', 'female'),
#  ('keilany', 'female'),
#  ('larrissa', 'female'),
#  ('macy', 'female'),
#  ('fenton', 'male'),
#  ('harlon', 'male'),
#  ('altariq', 'male'),
#  ('haille', 'female'),
#  ('caedan', 'male'),
#  ('bernyce', 'female'),
#  ('ronnell', 'male'),
#  ('charlonda', 'female'),
#  ('dulcemaria', 'female'),
#  ('melkam', 'male'),
#  ('zoann', 'female'),
#  ('kilyan', 'male'),
#  ('maeby', 'female'),
#  ('blayde', 'male'),
#  ('raylinn', 'female'),
#  ('ercolino', 'male'),
#  ('jaylisse', 'female'),
#  ('chantoria', 'female'),
#  ('nahomy', 'female'),
#  ('cully', 'male'),
#  ('anca', 'female'),
#  ('margunde', 'female'),
#  ('bahi', 'male'),
#  ('joannemarie', 'female'),
#  ('jelisa', 'female'),
#  ('johua', 'male'),
#  ('suppiah', 'male'),
#  ('kwali', 'male'),
#  ('shichang', 'male'),
#  ('inocentia', 'female'),
#  ('tomosuke', 'male'),
#  ('manville', 'male'),
#  ('dikla', 'female'),
#  ('shikara', 'female'),
#  ('chanie', 'female'),
#  ('shmiel', 'male'),
#  ('rodrecus', 'male'),
#  ('javed', 'male'),
#  ('clidie', 'female'),
#  ('evangelene', 'female'),
#  ('asaf', 'male'),
#  ('myalyn', 'female'),
#  ('madelinerose', 'female'),
#  ('kawtar', 'female'),
#  ('toyoaki', 'male'),
#  ('natasha', 'female'),
#  ('lynzy', 'female'),
#  ('jochum', 'male'),
#  ('matias', 'male'),
#  ('mandea', 'female'),
#  ('dietlind', 'female'),
#  ('turo', 'male'),
#  ('daretta', 'female'),
#  ('aqua', 'female'),
#  ('isahia', 'male'),
#  ('adiella', 'female'),
#  ('klasina', 'female'),
#  ('saveria', 'female'),
#  ('jaquelinee', 'female'),
#  ('clemensa', 'female'),
#  ('pertef', 'female'),
#  ('cove', 'male'),
#  ('braxlee', 'male'),
#  ('cleaveland', 'male'),
#  ('dornisha', 'female'),
#  ('mikynlee', 'female'),
#  ('jrgen', 'male'),
#  ('edelin', 'female'),
#  ('jaired', 'male'),
#  ('linay', 'female'),
#  ('lilah', 'female'),
#  ('enio', 'male'),
#  ('sindy', 'female'),
#  ('chaia', 'female'),
#  ('manjiri', 'female'),
#  ('xiujin', 'male'),
#  ('abbiegail', 'female'),
#  ('rosale', 'female'),
#  ('ardy', 'male'),
#  ('sherif', 'male'),
#  ('milnor', 'male'),
#  ('maeola', 'female'),
#  ('dearius', 'male'),
#  ('fatou', 'female'),
#  ('kaytee', 'female'),
#  ('elon', 'male'),
#  ('kayleigh', 'female'),
#  ('angeliese', 'female'),
#  ('kailene', 'female'),
#  ('ehrentrudis', 'female'),
#  ('avijit', 'male'),
#  ('daegon', 'male'),
#  ('florin', 'male'),
#  ('arkady', 'male'),
#  ('xingquan', 'male'),
#  ('elbira', 'female'),
#  ('gabrel', 'male'),
#  ('goe', 'male'),
#  ('cigi', 'female'),
#  ('jodel', 'female'),
#  ('rumaysa', 'female'),
#  ('mareke', 'female'),
#  ('gursirat', 'female'),
#  ('jaderion', 'male'),
#  ('marris', 'male'),
#  ('izyah', 'male'),
#  ('lucas', 'male'),
#  ('dayanira', 'female'),
#  ('priestly', 'male'),
#  ('yunqiu', 'male'),
#  ('loric', 'male'),
#  ('shelby', 'female'),
#  ('sigrur', 'female'),
#  ('leiliani', 'female'),
#  ('braylie', 'female'),
#  ('devendra', 'male'),
#  ('bernnadette', 'female'),
#  ('sunder', 'male'),
#  ('yarisbel', 'female'),
#  ('yarelii', 'female'),
#  ('glyniss', 'female'),
#  ('intisar', 'female'),
#  ('concettina', 'female'),
#  ('jameion', 'male'),
#  ('caltlin', 'female'),
#  ('ludvina', 'female'),
#  ('imberly', 'female'),
#  ('dema', 'female'),
#  ('leilanni', 'female'),
#  ('marcellis', 'male'),
#  ('lenabelle', 'female'),
#  ('lareesa', 'female'),
#  ('emilian', 'male'),
#  ('tyleia', 'female'),
#  ('torella', 'female'),
#  ('sedko', 'male'),
#  ('lenneke', 'female'),
#  ('jaycie', 'female'),
#  ('deveah', 'female'),
#  ('wendy', 'male'),
#  ('bhopinder', 'male'),
#  ('brizza', 'female'),
#  ('tristen', 'male'),
#  ('bet', 'female'),
#  ('kiniah', 'female'),
#  ('yiying', 'male'),
#  ('shyloh', 'female'),
#  ('coddy', 'male'),
#  ('yusif', 'male'),
#  ('shadyn', 'female'),
#  ('eduin', 'male'),
#  ('ilayda', 'female'),
#  ('cherline', 'female'),
#  ('madlen', 'female'),
#  ('simpson', 'male'),
#  ('neshay', 'female'),
#  ('guangdi', 'male'),
#  ('girishchandra', 'male'),
#  ('arsnio', 'male'),
#  ('tirek', 'male'),
#  ('binbin', 'male'),
#  ('alleya', 'female'),
#  ('karalyn', 'female'),
#  ('nyjee', 'male'),
#  ('heisy', 'female'),
#  ('anneloes', 'female'),
#  ('evrard', 'male'),
#  ('gaiden', 'male'),
#  ('franjo', 'male'),
#  ('adahy', 'male'),
#  ('hamite', 'female'),
#  ('tabaitha', 'female'),
#  ('rasaiah', 'male'),
#  ('sy', 'male'),
#  ('mitsuru', 'male'),
#  ('zykiria', 'female'),
#  ('cleona', 'female'),
#  ('taffi', 'male'),
#  ('starnisha', 'female'),
#  ('annon', 'male'),
#  ('hermon', 'male'),
#  ('johnika', 'female'),
#  ('nolla', 'female'),
#  ('zhan', 'male'),
#  ('alaija', 'female'),
#  ('saifoulaye', 'female'),
#  ('aleece', 'female'),
#  ('yongsen', 'male'),
#  ('verley', 'female'),
#  ('yuanlong', 'male'),
#  ('jaiyana', 'female'),
#  ('jieying', 'male'),
#  ('kyrston', 'female'),
#  ('tieler', 'male'),
#  ('guoquan', 'male'),
#  ('shanarra', 'female'),
#  ('gerfried', 'male'),
#  ('marsibil', 'female'),
#  ('everdina', 'female'),
#  ('dao', 'male'),
#  ('dion', 'male'),
#  ('tell', 'male'),
#  ('xiangwei', 'male'),
#  ('hongdi', 'male'),
#  ('mykisha', 'female'),
#  ('jourdan', 'female'),
#  ('garlond', 'male'),
#  ('dervla', 'female'),
#  ('gunder', 'male'),
#  ('hilmo', 'male'),
#  ('bjartur', 'male'),
#  ('eshter', 'female'),
#  ('tamiia', 'female'),
#  ('margulia', 'female'),
#  ('arseni', 'male'),
#  ('esekiel', 'male'),
#  ('gianguido', 'male'),
#  ('shatifah', 'female'),
#  ('trasen', 'male'),
#  ('evynn', 'female'),
#  ('paeten', 'female'),
#  ('naol', 'male'),
#  ('xiaoyun', 'male'),
#  ('irmgardt', 'female'),
#  ('marleny', 'female'),
#  ('dayanari', 'female'),
#  ('salomeja', 'female'),
#  ('zuowei', 'male'),
#  ('odas', 'male'),
#  ('jeyakumaran', 'male'),
#  ('teodulo', 'male'),
#  ('camilah', 'female'),
#  ('kajuan', 'male'),
#  ('quazi', 'male'),
#  ('kainoah', 'male'),
#  ('yedaiah', 'male'),
#  ('sharonlee', 'female'),
#  ('jaysan', 'male'),
#  ('joyclyn', 'female'),
#  ('mateus', 'male'),
#  ('oza', 'female'),
#  ('pracilla', 'female'),
#  ('seanmatthew', 'male'),
#  ('johnella', 'female'),
#  ('ezmie', 'female'),
#  ('jaquan', 'male'),
#  ('rumer', 'female'),
#  ('eriqua', 'female'),
#  ('orien', 'male'),
#  ('amanee', 'female'),
#  ('taiwan', 'male'),
#  ('abhik', 'male'),
#  ('othelia', 'female'),
#  ('uvo', 'male'),
#  ('deylani', 'female'),
#  ('virgin', 'female'),
#  ('eliseiu', 'male'),
#  ('beatrijs', 'female'),
#  ('lutisha', 'female'),
#  ('lestine', 'female'),
#  ('vilfrur', 'female'),
#  ('ashantie', 'female'),
#  ('cyrine', 'female'),
#  ('charolett', 'female'),
#  ('mikee', 'male'),
#  ('ljuban', 'male'),
#  ('fortino', 'male'),
#  ('takamichi', 'male'),
#  ('avant', 'male'),
#  ('katharien', 'female'),
#  ('amorra', 'female'),
#  ('billy', 'male'),
#  ('kalib', 'male'),
#  ('analuz', 'female'),
#  ('debb', 'female'),
#  ('aurlien', 'male'),
#  ('paitin', 'female'),
#  ('holly', 'female'),
#  ('onisha', 'female'),
#  ('jackhenry', 'male'),
#  ('lyah', 'female'),
#  ('jarhett', 'male'),
#  ('wanjuan', 'male'),
#  ('milyana', 'female'),
#  ('alaysa', 'female'),
#  ('erkmar', 'male'),
#  ('jadakis', 'male'),
#  ('erwei', 'male'),
#  ('kolyn', 'male'),
#  ('altrice', 'female'),
#  ('jaruis', 'male'),
#  ('aniqua', 'female'),
#  ('tykwon', 'male'),
#  ('tahirah', 'female'),
#  ('emmiliano', 'male'),
#  ('zongming', 'male'),
#  ('markle', 'male'),
#  ('allysan', 'female'),
#  ('thelisa', 'female'),
#  ('sirenia', 'female'),
#  ('presciliano', 'male'),
#  ('baiyang', 'male'),
#  ('kdynn', 'male'),
#  ('odalis', 'female'),
#  ('leonard', 'male'),
#  ('berry', 'male'),
#  ('milroy', 'male'),
#  ('lekesha', 'female'),
#  ('sayonna', 'female'),
#  ('tecumseh', 'male'),
#  ('itsel', 'female'),
#  ('namhyun', 'male'),
#  ('matalie', 'female'),
#  ('meeghan', 'female'),
#  ('renald', 'male'),
#  ('keir', 'male'),
#  ('kariel', 'female'),
#  ('shams', 'female'),
#  ('kahle', 'male'),
#  ('fulbert', 'male'),
#  ('jhair', 'male'),
#  ('shabhana', 'female'),
#  ('alfina', 'female'),
#  ('velie', 'female'),
#  ('aleka', 'female'),
#  ('sharrie', 'female'),
#  ('chiriac', 'male'),
#  ('briceyda', 'female'),
#  ('xavy', 'male'),
#  ('aihua', 'male'),
#  ('zejnie', 'female'),
#  ('machteld', 'female'),
#  ('davanna', 'female'),
#  ('jakyrie', 'male'),
#  ('ljubov', 'female'),
#  ('taveyon', 'male'),
#  ('qifan', 'male'),
#  ('ezaria', 'female'),
#  ('theodorus', 'male'),
#  ('aaleiyah', 'female'),
#  ('lunie', 'female'),
#  ('stefanie', 'female'),
#  ('braydon', 'male'),
#  ('saloma', 'female'),
#  ('kaitlen', 'female'),
#  ('ishanvi', 'female'),
#  ('milenija', 'female'),
#  ('dikran', 'male'),
#  ('nelsen', 'male'),
#  ('anferny', 'male'),
#  ('brynja', 'female'),
#  ('edmanuel', 'male'),
#  ('lita', 'female'),
#  ('quavis', 'male'),
#  ('danley', 'male'),
#  ('gertmund', 'male'),
#  ('achicam', 'male'),
#  ('guangde', 'male'),
#  ('calton', 'male'),
#  ('verile', 'female'),
#  ('nily', 'female'),
#  ('dorane', 'female'),
#  ('micaden', 'male'),
#  ('christine', 'male'),
#  ('derward', 'male'),
#  ('cristalyn', 'female'),
#  ('raejean', 'female'),
#  ('eulises', 'male'),
#  ('bodie', 'male'),
#  ('tasheyana', 'female'),
#  ('lore', 'female'),
#  ('luell', 'female'),
#  ('krisi', 'female'),
#  ('bannon', 'male'),
#  ('ilchung', 'male'),
#  ('neysa', 'female'),
#  ('dylanthomas', 'male'),
#  ('angxuanemanuel', 'male'),
#  ('yuanping', 'male'),
#  ('arkeisha', 'female'),
#  ('quevin', 'male'),
#  ('alarich', 'male'),
#  ('latedra', 'female'),
#  ('kiymet', 'female'),
#  ('mishelle', 'female'),
#  ('danahe', 'female'),
#  ('kanichi', 'male'),
#  ('lume', 'female'),
#  ('grimm', 'male'),
#  ('virmantas', 'male'),
#  ('neyamiah', 'female'),
#  ('heyli', 'female'),
#  ('zhengping', 'male'),
#  ('jarexi', 'female'),
#  ('jahmauri', 'male'),
#  ('karesse', 'female'),
#  ('manoil', 'male'),
#  ('nathnael', 'male'),
#  ('mesai', 'male'),
#  ('trinese', 'female'),
#  ('santhirasegaram', 'male'),
#  ('katisha', 'female'),
#  ('soh', 'male'),
#  ('kenneth', 'male'),
#  ('mealea', 'female'),
#  ('changyi', 'male'),
#  ('fazli', 'male'),
#  ('vennetta', 'female'),
#  ('yuanyuan', 'male'),
#  ('sandrea', 'female'),
#  ('wilfried', 'male'),
#  ('alliana', 'female'),
#  ('aeriona', 'female'),
#  ('shafee', 'male'),
#  ('diquan', 'male'),
#  ('keerat', 'female'),
#  ('breya', 'female'),
#  ('sungh', 'male'),
#  ('loie', 'female'),
#  ('jassim', 'male'),
#  ('crmen', 'female'),
#  ('didiana', 'male'),
#  ('niculita', 'female'),
#  ('brandee', 'female'),
#  ('rolen', 'male'),
#  ('trevan', 'male'),
#  ('vreny', 'female'),
#  ('amichai', 'male'),
#  ('yunfu', 'male'),
#  ('aamiya', 'female'),
#  ('airiana', 'female'),
#  ('zhulijan', 'male'),
#  ('shaliese', 'female'),
#  ('mikey', 'male'),
#  ('miasha', 'female'),
#  ('rhya', 'female'),
#  ('malasha', 'female'),
#  ('cuno', 'male'),
#  ('laurenske', 'female'),
#  ('syble', 'female'),
#  ('alphan', 'male'),
#  ('tresatheresa', 'male'),
#  ('twanisha', 'female'),
#  ('mackenzey', 'female'),
#  ('adalee', 'female'),
#  ('guojin', 'male'),
#  ('tietje', 'male'),
#  ('darnecia', 'female'),
#  ('laqresha', 'female'),
#  ('sunbeam', 'female'),
#  ('nyelah', 'female'),
#  ('belmeda', 'female'),
#  ('litterio', 'male'),
#  ('yanal', 'male'),
#  ('stamo', 'male'),
#  ('fani', 'female'),
#  ('terzia', 'female'),
#  ('xianfa', 'male'),
#  ('medha', 'female'),
#  ('luzetta', 'female'),
#  ('veerle', 'female'),
#  ('wildred', 'female'),
#  ('monee', 'female'),
#  ('buffi', 'female'),
#  ('cyncere', 'male'),
#  ('jianfen', 'male'),
#  ('krzysztof', 'male'),
#  ('kinverli', 'female'),
#  ('momoyo', 'female'),
#  ('ginni', 'female'),
#  ('tricity', 'female'),
#  ('crosby', 'male'),
#  ('leonharda', 'female'),
#  ('kelbie', 'female'),
#  ('selwa', 'female'),
#  ('dual', 'male'),
#  ('jamilyn', 'female'),
#  ('tehran', 'male'),
#  ('meerub', 'female'),
#  ('marielle', 'female'),
#  ('trayvis', 'male'),
#  ('ilirjana', 'female'),
#  ('melida', 'female'),
#  ('emojean', 'female'),
#  ('avynn', 'female'),
#  ('wakeem', 'male'),
#  ('cerita', 'female'),
#  ('catherin', 'female'),
#  ('andruw', 'male'),
#  ('calek', 'male'),
#  ('solea', 'female'),
#  ('ivanciu', 'male'),
#  ('kearstyn', 'female'),
#  ('catalya', 'female'),
#  ('reniqua', 'female'),
#  ('ajeta', 'female'),
#  ('malvna', 'female'),
#  ('arno', 'male'),
#  ('bidisha', 'female'),
#  ('tylashia', 'female'),
#  ('roelfiene', 'female'),
#  ('marusja', 'female'),
#  ('ishan', 'male'),
#  ('jaser', 'male'),
#  ('rasaan', 'male'),
#  ('kyun', 'male'),
#  ('keiajah', 'female'),
#  ('coralin', 'female'),
#  ('aishe', 'female'),
#  ('greysi', 'female'),
#  ('jerrold', 'male'),
#  ('elysa', 'female'),
#  ('andelin', 'female'),
#  ('bertaberti', 'male'),
#  ('jaksyn', 'male'),
#  ('shirly', 'female'),
#  ('mildaras', 'male'),
#  ('akiria', 'female'),
#  ('joerg', 'male'),
#  ('cateena', 'female'),
#  ('ammi', 'female'),
#  ('abia', 'female'),
#  ('darcie', 'female'),
#  ('ludelle', 'female'),
#  ('siebe', 'male'),
#  ('jamius', 'male'),
#  ('aldona', 'female'),
#  ('adriah', 'female'),
#  ('azi', 'male'),
#  ('malulani', 'female'),
#  ('rinoa', 'female'),
#  ('aleesia', 'female'),
#  ('lillyauna', 'female'),
#  ('sachiel', 'male'),
#  ('veit', 'male'),
#  ('norietta', 'female'),
#  ('bringfried', 'male'),
#  ('kariyah', 'female'),
#  ('sabrie', 'female'),
#  ('latrell', 'male'),
#  ('cisco', 'male'),
#  ('joemar', 'male'),
#  ('arijit', 'male'),
#  ('soliana', 'female'),
#  ('johntel', 'male'),
#  ('anegla', 'female'),
#  ('wilmont', 'male'),
#  ('mariama', 'female'),
#  ('jannali', 'female'),
#  ('juneve', 'female'),
#  ('jamaiah', 'female'),
#  ('meinard', 'male'),
#  ('jaquith', 'female'),
#  ('zalayah', 'female'),
#  ('delrae', 'female'),
#  ('laleta', 'female'),
#  ('effrem', 'male'),
#  ('sherice', 'female'),
#  ('odalia', 'female'),
#  ('sharnisha', 'female'),
#  ('ashalina', 'female'),
#  ('alcdia', 'female'),
#  ('taru', 'female'),
#  ('lynnai', 'female'),
#  ('krishang', 'male'),
#  ('yunalesca', 'female'),
#  ('misiu', 'female'),
#  ('brohdy', 'male'),
#  ('frigyes', 'male'),
#  ('reubin', 'male'),
#  ('andrianne', 'female'),
#  ('ursola', 'female'),
#  ('khushboo', 'female'),
#  ('janssen', 'male'),
#  ('yakov', 'male'),
#  ('lyniah', 'female'),
#  ('mylez', 'male'),
#  ('sooad', 'female'),
#  ('taranika', 'female'),
#  ('dimo', 'male'),
#  ('ina', 'female'),
#  ('cashon', 'male'),
#  ('kaicee', 'female'),
#  ('elahni', 'female'),
#  ('dameshia', 'female'),
#  ('marcile', 'female'),
#  ('brandilyn', 'female'),
#  ('afaf', 'female'),
#  ('hadleigh', 'female'),
#  ('statham', 'male'),
#  ('ruban', 'male'),
#  ('ted', 'male'),
#  ('sarafina', 'female'),
#  ('charday', 'female'),
#  ('madoc', 'male'),
#  ('helio', 'male'),
#  ('sevana', 'female'),
#  ('terriyah', 'female'),
#  ('muhyiddin', 'male'),
#  ('alyca', 'female'),
#  ('joanny', 'female'),
#  ('arainna', 'female'),
#  ('gojka', 'female'),
#  ('tobiann', 'female'),
#  ('chelcie', 'female'),
#  ('fuhai', 'male'),
#  ('ritva', 'female'),
#  ('willies', 'male'),
#  ('lynleigh', 'female'),
#  ('syl', 'male'),
#  ('cazim', 'male'),
#  ('crandall', 'male'),
#  ('horea', 'male'),
#  ('derold', 'male'),
#  ('abish', 'female'),
#  ('mayo', 'female'),
#  ('kinuyo', 'female'),
#  ('cristeen', 'female'),
#  ('caterin', 'female'),
#  ('siddeeq', 'male'),
#  ('jionny', 'male'),
#  ('taivo', 'male'),
#  ...]

# %%
loadDataset(False)
# Out:
# [('ginnifer', 'female'),
#  ('veer', 'male'),
#  ('agustya', 'male'),
#  ('jaheam', 'male'),
#  ('kesly', 'female'),
#  ('sreehan', 'male'),
#  ('ernisha', 'female'),
#  ('mirjam', 'female'),
#  ('perna', 'female'),
#  ('kylematthew', 'male'),
#  ('deshone', 'male'),
#  ('ajisha', 'female'),
#  ('dezhan', 'male'),
#  ('sevryn', 'male'),
#  ('foppe', 'male'),
#  ('thinh', 'male'),
#  ('saniyah', 'female'),
#  ('brityn', 'female'),
#  ('tekeira', 'female'),
#  ('avry', 'female'),
#  ('annunziato', 'male'),
#  ('lizeht', 'female'),
#  ('alcdia', 'female'),
#  ('gurlie', 'female'),
#  ('reeya', 'female'),
#  ('vinay', 'male'),
#  ('seoyoon', 'female'),
#  ('evisa', 'female'),
#  ('renado', 'male'),
#  ('miyona', 'female'),
#  ('vaira', 'female'),
#  ('rupi', 'female'),
#  ('aella', 'female'),
#  ('dagbjrt', 'female'),
#  ('mairtn', 'male'),
#  ('konstantinos', 'male'),
#  ('shadee', 'female'),
#  ('augustis', 'male'),
#  ('chanden', 'male'),
#  ('gearald', 'male'),
#  ('shaunea', 'female'),
#  ('treton', 'male'),
#  ('yishu', 'male'),
#  ('darrlyn', 'male'),
#  ('cashion', 'male'),
#  ('dekin', 'male'),
#  ('ophelia', 'male'),
#  ('xialin', 'male'),
#  ('leran', 'female'),
#  ('josealfredo', 'male'),
#  ('chunghsiung', 'male'),
#  ('clevester', 'male'),
#  ('hatixhe', 'female'),
#  ('youqin', 'male'),
#  ('melwin', 'male'),
#  ('neosha', 'female'),
#  ('analiyah', 'female'),
#  ('suraya', 'female'),
#  ('pawnee', 'female'),
#  ('najmah', 'female'),
#  ('xiumei', 'male'),
#  ('miriama', 'female'),
#  ('chieu', 'male'),
#  ('rhylea', 'female'),
#  ('wenchao', 'male'),
#  ('dejuane', 'male'),
#  ('starling', 'male'),
#  ('pacey', 'male'),
#  ('marieka', 'female'),
#  ('selinde', 'female'),
#  ('lanjin', 'male'),
#  ('chaneice', 'female'),
#  ('addsion', 'female'),
#  ('kyerstin', 'female'),
#  ('forida', 'female'),
#  ('kamia', 'female'),
#  ('amechi', 'male'),
#  ('munir', 'male'),
#  ('eldana', 'female'),
#  ('serani', 'male'),
#  ('night', 'female'),
#  ('brittanae', 'female'),
#  ('sadeq', 'male'),
#  ('briyon', 'male'),
#  ('gisel', 'female'),
#  ('ninagiovanna', 'male'),
#  ('tynise', 'female'),
#  ('minaksi', 'male'),
#  ('shikari', 'female'),
#  ('deva', 'female'),
#  ('radita', 'female'),
#  ('merika', 'female'),
#  ('jacobmatthew', 'male'),
#  ('lakedrick', 'male'),
#  ('chanele', 'female'),
#  ('treshaun', 'male'),
#  ('aleighanna', 'female'),
#  ('mileydi', 'female'),
#  ('tiembinus', 'male'),
#  ('freimut', 'male'),
#  ('kasai', 'male'),
#  ('younjoo', 'female'),
#  ('farudin', 'male'),
#  ('fitzhugh', 'male'),
#  ('sarriyah', 'female'),
#  ('edela', 'female'),
#  ('emilo', 'male'),
#  ('zhengtao', 'male'),
#  ('mialee', 'female'),
#  ('nitaya', 'female'),
#  ('hulene', 'female'),
#  ('shavonn', 'female'),
#  ('cheridan', 'female'),
#  ('rip', 'male'),
#  ('yosmar', 'male'),
#  ('chaena', 'female'),
#  ('fransisca', 'female'),
#  ('sidika', 'female'),
#  ('garv', 'male'),
#  ('garyon', 'male'),
#  ('quyet', 'male'),
#  ('airyonna', 'female'),
#  ('mrinal', 'female'),
#  ('roxxi', 'female'),
#  ('araf', 'male'),
#  ('taddeo', 'male'),
#  ('novaya', 'female'),
#  ('lataija', 'female'),
#  ('daleesa', 'female'),
#  ('tranquilla', 'female'),
#  ('ambroziu', 'male'),
#  ('luiggi', 'male'),
#  ('sueelle', 'female'),
#  ('yakeem', 'male'),
#  ('skylarrose', 'female'),
#  ('onalee', 'female'),
#  ('aquila', 'female'),
#  ('harlei', 'female'),
#  ('hrmar', 'male'),
#  ('marvia', 'female'),
#  ('zophie', 'female'),
#  ('marsue', 'female'),
#  ('cordey', 'male'),
#  ('naut', 'male'),
#  ('ibbo', 'male'),
#  ('mikemichael', 'male'),
#  ('manson', 'male'),
#  ('hydia', 'female'),
#  ('azelene', 'female'),
#  ('deshawnna', 'female'),
#  ('tauheedah', 'female'),
#  ('lolkje', 'female'),
#  ('aryk', 'male'),
#  ('kassiah', 'female'),
#  ('michiru', 'female'),
#  ('atalay', 'male'),
#  ('mekyla', 'female'),
#  ('heingert', 'male'),
#  ('jingdong', 'male'),
#  ('kiwana', 'female'),
#  ('sucely', 'female'),
#  ('heinie', 'female'),
#  ('zayuri', 'female'),
#  ('refki', 'male'),
#  ('yuko', 'male'),
#  ('camrun', 'male'),
#  ('bitte', 'female'),
#  ('lavie', 'female'),
#  ('clesta', 'female'),
#  ('heiko', 'male'),
#  ('rosenia', 'female'),
#  ('dongxiang', 'male'),
#  ('ianthus', 'male'),
#  ('rece', 'male'),
#  ('erlgard', 'female'),
#  ('aliyiah', 'female'),
#  ('ellorie', 'female'),
#  ('fantaysia', 'female'),
#  ('ehren', 'male'),
#  ('nasheem', 'male'),
#  ('cordel', 'male'),
#  ('tren', 'male'),
#  ('rumyanka', 'female'),
#  ('lujane', 'female'),
#  ('jisiah', 'male'),
#  ('brayanna', 'female'),
#  ('saschaaleksandr', 'male'),
#  ('raven', 'female'),
#  ('heorhi', 'male'),
#  ('adaja', 'female'),
#  ('basimah', 'female'),
#  ('edvige', 'female'),
#  ('shandra', 'female'),
#  ('wingate', 'male'),
#  ('debriana', 'female'),
#  ('shenea', 'female'),
#  ('zilin', 'female'),
#  ('deiona', 'female'),
#  ('rejina', 'female'),
#  ('shutao', 'male'),
#  ('subeda', 'female'),
#  ('theodoula', 'female'),
#  ('samorah', 'female'),
#  ('lovelyn', 'female'),
#  ('qiqiang', 'male'),
#  ('malaeka', 'female'),
#  ('maimo', 'female'),
#  ('divansh', 'male'),
#  ('annekatrin', 'female'),
#  ('ovida', 'female'),
#  ('dzenana', 'female'),
#  ('fenn', 'male'),
#  ('dazhan', 'male'),
#  ('yadian', 'male'),
#  ('tomoki', 'male'),
#  ('zeylah', 'female'),
#  ('ruhong', 'male'),
#  ('leylany', 'female'),
#  ('winnefred', 'female'),
#  ('priscyla', 'female'),
#  ('jerine', 'female'),
#  ('zhiguo', 'male'),
#  ('carlyann', 'female'),
#  ('uless', 'male'),
#  ('ruzica', 'female'),
#  ('bralyn', 'male'),
#  ('pirkko', 'female'),
#  ('amilliona', 'female'),
#  ('grey', 'male'),
#  ('shametria', 'female'),
#  ('sabreea', 'female'),
#  ('zoe', 'female'),
#  ('dajanay', 'female'),
#  ('bobbye', 'female'),
#  ('keally', 'female'),
#  ('leiasia', 'female'),
#  ('rosezanna', 'female'),
#  ('asle', 'male'),
#  ('jerrolyn', 'female'),
#  ('jehoshua', 'male'),
#  ('octavie', 'female'),
#  ('xuelin', 'male'),
#  ('jacobje', 'female'),
#  ('eiza', 'female'),
#  ('angeliina', 'female'),
#  ('strickland', 'male'),
#  ('avenly', 'female'),
#  ('khelani', 'female'),
#  ('zephram', 'male'),
#  ('jinkyong', 'female'),
#  ('coleta', 'female'),
#  ('ervena', 'female'),
#  ('arlana', 'female'),
#  ('maleki', 'male'),
#  ('preksha', 'female'),
#  ('auschvidas', 'male'),
#  ('jingting', 'female'),
#  ('gnsel', 'female'),
#  ('akieba', 'female'),
#  ('malenny', 'female'),
#  ('heloisa', 'female'),
#  ('raakkeli', 'female'),
#  ('machi', 'female'),
#  ('jillena', 'female'),
#  ('ailsa', 'female'),
#  ('shuzhen', 'male'),
#  ('mackenlee', 'female'),
#  ('alnora', 'female'),
#  ('prabha', 'female'),
#  ('mercan', 'male'),
#  ('marven', 'male'),
#  ('chas', 'male'),
#  ('sinatra', 'male'),
#  ('sajad', 'male'),
#  ('gus', 'male'),
#  ('aristotel', 'male'),
#  ('torge', 'male'),
#  ('kizi', 'female'),
#  ('errico', 'male'),
#  ('johann', 'male'),
#  ('ereny', 'female'),
#  ('sourish', 'male'),
#  ('caelainn', 'female'),
#  ('pasquina', 'female'),
#  ('krisha', 'female'),
#  ('hjalmer', 'male'),
#  ('chantai', 'female'),
#  ('brother', 'male'),
#  ('everlyse', 'female'),
#  ('geneta', 'female'),
#  ('mathura', 'female'),
#  ('matigan', 'female'),
#  ('shanterri', 'female'),
#  ('bridy', 'female'),
#  ('radomila', 'female'),
#  ('eftimita', 'female'),
#  ('kiril', 'male'),
#  ('demarrie', 'male'),
#  ('willfredo', 'male'),
#  ('ahleigha', 'female'),
#  ('kortny', 'female'),
#  ('kanai', 'male'),
#  ('terryana', 'female'),
#  ('jovannie', 'male'),
#  ('kyrianna', 'female'),
#  ('alieshia', 'female'),
#  ('paresh', 'male'),
#  ('quanzie', 'male'),
#  ('bernda', 'female'),
#  ('sande', 'male'),
#  ('auni', 'female'),
#  ('ephrim', 'male'),
#  ('nyveah', 'female'),
#  ('eirlys', 'female'),
#  ('crowell', 'male'),
#  ('keandrae', 'male'),
#  ('indyah', 'female'),
#  ('dravid', 'male'),
#  ('blayde', 'male'),
#  ('angelou', 'male'),
#  ('yongbo', 'male'),
#  ('grarde', 'female'),
#  ('tisa', 'female'),
#  ('aglar', 'male'),
#  ('alva', 'male'),
#  ('nkara', 'female'),
#  ('chyene', 'female'),
#  ('tramar', 'male'),
#  ('jamess', 'male'),
#  ('jacquelin', 'female'),
#  ('salvina', 'female'),
#  ('jaylond', 'male'),
#  ('joya', 'female'),
#  ('amiyiah', 'female'),
#  ('melmelanie', 'male'),
#  ('delton', 'male'),
#  ('majuma', 'female'),
#  ('baldvina', 'female'),
#  ('melo', 'male'),
#  ('gulnara', 'female'),
#  ('haines', 'male'),
#  ('feride', 'female'),
#  ('gracinda', 'female'),
#  ('chaoyang', 'male'),
#  ('kieva', 'female'),
#  ('duell', 'male'),
#  ('cambriah', 'female'),
#  ('soini', 'female'),
#  ('mohamedhalimbin', 'male'),
#  ('akura', 'female'),
#  ('romualds', 'male'),
#  ('namirah', 'female'),
#  ('javantay', 'male'),
#  ('arlynes', 'female'),
#  ('rockson', 'male'),
#  ('anaclara', 'female'),
#  ('maureena', 'female'),
#  ('yirui', 'male'),
#  ('breelynn', 'female'),
#  ('nouri', 'male'),
#  ('alecxa', 'female'),
#  ('dahe', 'male'),
#  ('zhair', 'male'),
#  ('josie', 'female'),
#  ('bingru', 'male'),
#  ('hajohansjoachim', 'male'),
#  ('zulfija', 'female'),
#  ('timarion', 'male'),
#  ('peggy', 'male'),
#  ('trevis', 'male'),
#  ('luisgerardo', 'male'),
#  ('doralin', 'female'),
#  ('zykeem', 'male'),
#  ('fenyu', 'male'),
#  ('kamara', 'female'),
#  ('shanoa', 'female'),
#  ('javed', 'male'),
#  ('keniel', 'male'),
#  ('pasquino', 'male'),
#  ('alius', 'male'),
#  ('mironica', 'female'),
#  ('shian', 'female'),
#  ('lanceton', 'male'),
#  ('myalin', 'female'),
#  ('atheana', 'female'),
#  ('dimitrija', 'male'),
#  ('borjanka', 'female'),
#  ('saroun', 'female'),
#  ('naryia', 'female'),
#  ('leshell', 'female'),
#  ('johnathen', 'male'),
#  ('rocelyn', 'female'),
#  ('lanaijah', 'female'),
#  ('etash', 'male'),
#  ('faylyn', 'female'),
#  ('maiquel', 'female'),
#  ('soila', 'female'),
#  ('laline', 'female'),
#  ('shaneice', 'female'),
#  ('massamba', 'male'),
#  ('heeya', 'female'),
#  ('johnnia', 'female'),
#  ('lydon', 'male'),
#  ('holleigh', 'female'),
#  ('alyeska', 'female'),
#  ('ionas', 'male'),
#  ('bernulf', 'male'),
#  ('gabina', 'female'),
#  ('meisje', 'female'),
#  ('mutlu', 'male'),
#  ('ameia', 'female'),
#  ('vashni', 'female'),
#  ('anaveah', 'female'),
#  ('zoeygrace', 'female'),
#  ('havva', 'female'),
#  ('zykierra', 'female'),
#  ('junathaen', 'male'),
#  ('balraj', 'male'),
#  ('traevin', 'male'),
#  ('jermane', 'male'),
#  ('laisheng', 'male'),
#  ('darthula', 'female'),
#  ('riobeard', 'male'),
#  ('kalib', 'male'),
#  ('lynnell', 'female'),
#  ('delci', 'female'),
#  ('akeena', 'female'),
#  ('bethsaida', 'female'),
#  ('sriskantharajah', 'male'),
#  ('nuhi', 'male'),
#  ('kamarien', 'male'),
#  ('rochanda', 'female'),
#  ('shaunee', 'female'),
#  ('illona', 'female'),
#  ('christfried', 'male'),
#  ('shambrica', 'female'),
#  ('minyoon', 'male'),
#  ('majida', 'female'),
#  ('maliss', 'female'),
#  ('belvin', 'male'),
#  ('miyake', 'male'),
#  ('zuleika', 'female'),
#  ('marjarie', 'female'),
#  ('neiko', 'male'),
#  ('glory', 'female'),
#  ('lakai', 'male'),
#  ('beda', 'male'),
#  ('starleigh', 'female'),
#  ('kaicee', 'female'),
#  ('chanell', 'female'),
#  ('lone', 'female'),
#  ('kathlena', 'female'),
#  ('levorne', 'male'),
#  ('remedi', 'female'),
#  ('elby', 'male'),
#  ('jura', 'female'),
#  ('kaedyn', 'male'),
#  ('viar', 'male'),
#  ('jogina', 'female'),
#  ('cristeen', 'female'),
#  ('albric', 'male'),
#  ('lyutcho', 'male'),
#  ('sanyia', 'female'),
#  ('harpergrace', 'female'),
#  ('reita', 'female'),
#  ('baldino', 'male'),
#  ('deztany', 'female'),
#  ('canasia', 'female'),
#  ('elyah', 'male'),
#  ('rishita', 'female'),
#  ('brano', 'male'),
#  ('milco', 'male'),
#  ('dominus', 'male'),
#  ('nollan', 'male'),
#  ('gytte', 'female'),
#  ('caithan', 'male'),
#  ('dasya', 'female'),
#  ('jakub', 'male'),
#  ('knightley', 'female'),
#  ('ulrich', 'male'),
#  ('shiliang', 'male'),
#  ('nafisa', 'female'),
#  ('shaelynne', 'female'),
#  ('zelva', 'female'),
#  ('nellie', 'female'),
#  ('nayli', 'female'),
#  ('mohinder', 'male'),
#  ('ilvis', 'male'),
#  ('akeil', 'male'),
#  ('chev', 'male'),
#  ('rohit', 'male'),
#  ('kilea', 'female'),
#  ('irbin', 'male'),
#  ('arti', 'male'),
#  ('heimhart', 'male'),
#  ('geralyn', 'female'),
#  ('chuy', 'male'),
#  ('dareus', 'male'),
#  ('petina', 'female'),
#  ('lianhua', 'male'),
#  ('anibella', 'female'),
#  ('eban', 'male'),
#  ('friedric', 'male'),
#  ('bland', 'male'),
#  ('viigo', 'male'),
#  ('velitchka', 'female'),
#  ('jondavid', 'male'),
#  ('agazio', 'male'),
#  ('dearie', 'female'),
#  ('inesis', 'male'),
#  ('isidro', 'male'),
#  ('cisely', 'female'),
#  ('kang', 'female'),
#  ('spandana', 'female'),
#  ('srbin', 'male'),
#  ('malikai', 'male'),
#  ('gugash', 'male'),
#  ('gottfried', 'male'),
#  ('kamaljit', 'male'),
#  ('kaymen', 'male'),
#  ('savonia', 'female'),
#  ('lrro', 'male'),
#  ('twilah', 'female'),
#  ('krieno', 'male'),
#  ('mekkah', 'female'),
#  ('rivan', 'male'),
#  ('nylani', 'female'),
#  ('marlan', 'male'),
#  ('jahzel', 'female'),
#  ('allyce', 'female'),
#  ('denny', 'male'),
#  ('roan', 'male'),
#  ('tilesha', 'female'),
#  ('taavi', 'male'),
#  ('chrysovalanti', 'female'),
#  ('anabel', 'female'),
#  ('drusiana', 'female'),
#  ('friedeborg', 'female'),
#  ('gianmichele', 'male'),
#  ('alwilda', 'female'),
#  ('izaias', 'male'),
#  ('alahni', 'female'),
#  ('aleiyah', 'female'),
#  ('lupie', 'female'),
#  ('ilani', 'female'),
#  ('heejoo', 'female'),
#  ('shaquetta', 'female'),
#  ('nayelin', 'female'),
#  ('moudie', 'female'),
#  ('gizi', 'female'),
#  ('zarana', 'female'),
#  ('kip', 'male'),
#  ('krenare', 'female'),
#  ('jesucita', 'female'),
#  ('noreli', 'female'),
#  ('mikos', 'male'),
#  ('makensey', 'female'),
#  ('jungyul', 'male'),
#  ('teruko', 'female'),
#  ('manique', 'female'),
#  ('zamiere', 'male'),
#  ('alve', 'male'),
#  ('souhair', 'female'),
#  ('jernya', 'female'),
#  ('brindin', 'male'),
#  ('taghrid', 'female'),
#  ('daschena', 'female'),
#  ('fadil', 'male'),
#  ('brijin', 'female'),
#  ('renitha', 'female'),
#  ('bethlielisabeth', 'male'),
#  ('likisha', 'female'),
#  ('xyana', 'female'),
#  ('ivajlo', 'male'),
#  ('thurayya', 'female'),
#  ('abdurrehman', 'male'),
#  ('leodegario', 'male'),
#  ('iolanda', 'female'),
#  ('herlin', 'male'),
#  ('mirjanka', 'female'),
#  ('slvi', 'female'),
#  ('jeffray', 'male'),
#  ('avenell', 'female'),
#  ('taahirah', 'female'),
#  ('micahya', 'female'),
#  ('zhengjie', 'male'),
#  ('michaelynn', 'female'),
#  ('caydence', 'female'),
#  ('aretha', 'female'),
#  ('coralia', 'female'),
#  ('marju', 'female'),
#  ('venis', 'female'),
#  ('davene', 'female'),
#  ('damir', 'male'),
#  ('zhenyaevgenija', 'male'),
#  ('ashana', 'female'),
#  ('yaismanuel', 'male'),
#  ('hoss', 'male'),
#  ('maizie', 'female'),
#  ('dazjah', 'female'),
#  ('areg', 'male'),
#  ('ebru', 'female'),
#  ('aliviana', 'female'),
#  ('kinsie', 'female'),
#  ('maozhen', 'male'),
#  ('zaima', 'female'),
#  ('gylfi', 'male'),
#  ('yasiris', 'female'),
#  ('lajaune', 'male'),
#  ('eloisa', 'female'),
#  ('franco', 'male'),
#  ('gevalia', 'female'),
#  ('sammeul', 'male'),
#  ('dominike', 'female'),
#  ('lewsong', 'male'),
#  ('lamontray', 'male'),
#  ('lynsie', 'female'),
#  ('colbi', 'female'),
#  ('arkell', 'male'),
#  ('jds', 'female'),
#  ('gildas', 'male'),
#  ('zadarius', 'male'),
#  ('myungsook', 'female'),
#  ('zahmere', 'male'),
#  ('daniette', 'female'),
#  ('jaicyon', 'male'),
#  ('gebkea', 'female'),
#  ('trevona', 'female'),
#  ('greisy', 'female'),
#  ('jenie', 'female'),
#  ('zaragoza', 'male'),
#  ('haowei', 'male'),
#  ('eudoxie', 'female'),
#  ('kamal', 'male'),
#  ('eftim', 'male'),
#  ('allam', 'male'),
#  ('imalay', 'female'),
#  ('zyrjeta', 'female'),
#  ('saviel', 'male'),
#  ('shatoni', 'female'),
#  ('dessarae', 'female'),
#  ('jenna', 'female'),
#  ('shandy', 'female'),
#  ('djeni', 'female'),
#  ('oreda', 'female'),
#  ('miaja', 'female'),
#  ('aleyna', 'female'),
#  ('graceyn', 'female'),
#  ('tennyson', 'male'),
#  ('yadong', 'male'),
#  ('surie', 'female'),
#  ('yarenys', 'female'),
#  ('hongzi', 'male'),
#  ('wendie', 'female'),
#  ('pavithra', 'female'),
#  ('dax', 'male'),
#  ('riki', 'male'),
#  ('maynord', 'male'),
#  ('yashar', 'male'),
#  ('nawana', 'female'),
#  ('mariliis', 'female'),
#  ('nete', 'female'),
#  ('greenwood', 'male'),
#  ('aydree', 'female'),
#  ('anavaeh', 'female'),
#  ('richierichard', 'male'),
#  ('ravendran', 'male'),
#  ('khamphiou', 'female'),
#  ('urosch', 'male'),
#  ('keanah', 'female'),
#  ('mlynn', 'female'),
#  ('suheyb', 'male'),
#  ('jkobi', 'male'),
#  ('juliahna', 'female'),
#  ('daquane', 'male'),
#  ('leonelle', 'female'),
#  ('jenabelle', 'female'),
#  ('odet', 'female'),
#  ('ulesses', 'male'),
#  ('mufinella', 'female'),
#  ('adaya', 'female'),
#  ('helmtraud', 'female'),
#  ('bonnitta', 'female'),
#  ('kimley', 'female'),
#  ('carr', 'male'),
#  ('aimei', 'male'),
#  ('hari', 'male'),
#  ('arnlaugur', 'male'),
#  ('wenlei', 'male'),
#  ('jerol', 'male'),
#  ('avaah', 'female'),
#  ('jcyon', 'male'),
#  ('karielys', 'female'),
#  ('ejlif', 'male'),
#  ('dezerey', 'female'),
#  ('dawson', 'male'),
#  ('adon', 'male'),
#  ('chongjiu', 'male'),
#  ('yoshinari', 'male'),
#  ('roxey', 'female'),
#  ('jaydalise', 'female'),
#  ('shoney', 'female'),
#  ('brianalee', 'female'),
#  ('bodi', 'male'),
#  ('layra', 'female'),
#  ('yanghong', 'male'),
#  ('towanna', 'female'),
#  ('emyia', 'female'),
#  ('sharmila', 'female'),
#  ('chenlong', 'male'),
#  ('changjiang', 'male'),
#  ('roobert', 'male'),
#  ('shallan', 'female'),
#  ('joeanna', 'female'),
#  ('barlina', 'female'),
#  ('colmon', 'male'),
#  ('teiah', 'female'),
#  ('barbel', 'female'),
#  ('jassem', 'male'),
#  ('zugui', 'male'),
#  ('chiffon', 'female'),
#  ('pearline', 'female'),
#  ('lence', 'female'),
#  ('moneta', 'female'),
#  ('nahrain', 'female'),
#  ('xamara', 'female'),
#  ('elizjah', 'male'),
#  ('griffith', 'male'),
#  ('leannah', 'female'),
#  ('lukretziya', 'female'),
#  ('leeum', 'male'),
#  ('uro', 'male'),
#  ('roeli', 'female'),
#  ('farryn', 'female'),
#  ('lynniah', 'female'),
#  ('sharman', 'female'),
#  ('zula', 'female'),
#  ('meigo', 'male'),
#  ('laquaysha', 'female'),
#  ('aneudy', 'male'),
#  ('chanavia', 'female'),
#  ('mubina', 'female'),
#  ('mays', 'male'),
#  ('almagul', 'female'),
#  ('gabino', 'male'),
#  ('bitao', 'male'),
#  ('cirillo', 'male'),
#  ('samora', 'female'),
#  ('kovid', 'male'),
#  ('dilja', 'female'),
#  ('kujtesa', 'female'),
#  ('maquita', 'female'),
#  ('viktar', 'male'),
#  ('valancia', 'female'),
#  ('yorleny', 'female'),
#  ('rafail', 'male'),
#  ('filuta', 'female'),
#  ('dariene', 'female'),
#  ('raeniyah', 'female'),
#  ('ameyalli', 'female'),
#  ('shauntia', 'female'),
#  ('ermnia', 'female'),
#  ('lashema', 'female'),
#  ('traven', 'male'),
#  ('merilou', 'female'),
#  ('jayco', 'male'),
#  ('mahlik', 'male'),
#  ('chenwen', 'male'),
#  ('cai', 'male'),
#  ('murriel', 'female'),
#  ('catreena', 'female'),
#  ('ponce', 'male'),
#  ('keaka', 'male'),
#  ('sidiki', 'male'),
#  ('lajps', 'male'),
#  ('keiundra', 'female'),
#  ('madge', 'female'),
#  ('denee', 'female'),
#  ('tugra', 'male'),
#  ('taseen', 'male'),
#  ('darold', 'male'),
#  ('rifadije', 'female'),
#  ('rhun', 'male'),
#  ('hasanah', 'female'),
#  ('jessus', 'male'),
#  ('laneesha', 'female'),
#  ('alfonce', 'male'),
#  ('blessn', 'female'),
#  ('quillon', 'male'),
#  ('kennie', 'male'),
#  ('joory', 'female'),
#  ('kavisha', 'female'),
#  ('yashir', 'male'),
#  ('calian', 'male'),
#  ('noella', 'female'),
#  ('zhuyu', 'male'),
#  ('leighlan', 'male'),
#  ('johhny', 'male'),
#  ('vincenzino', 'male'),
#  ('brekkin', 'male'),
#  ('lockwood', 'male'),
#  ('zniah', 'female'),
#  ('povilas', 'male'),
#  ('huihong', 'male'),
#  ('holta', 'female'),
#  ('sriyaan', 'male'),
#  ('kingelijah', 'male'),
#  ('marterrius', 'male'),
#  ('mingmei', 'male'),
#  ('aminna', 'female'),
#  ('rakwon', 'male'),
#  ('zenzele', 'female'),
#  ('kama', 'female'),
#  ('kika', 'female'),
#  ('devarsh', 'male'),
#  ('euijung', 'female'),
#  ('hazal', 'female'),
#  ('octavious', 'male'),
#  ('estela', 'female'),
#  ('mariselda', 'female'),
#  ('stevens', 'male'),
#  ('semira', 'female'),
#  ('qunita', 'female'),
#  ('angieangela', 'male'),
#  ('vitcho', 'male'),
#  ('vigan', 'male'),
#  ('ariz', 'male'),
#  ('brone', 'female'),
#  ('hasret', 'female'),
#  ('ronmel', 'male'),
#  ('hrissonka', 'female'),
#  ('onke', 'male'),
#  ('xiaonan', 'male'),
#  ('binyuan', 'male'),
#  ('libny', 'female'),
#  ('jinlei', 'male'),
#  ('heneretta', 'female'),
#  ('jasuan', 'male'),
#  ('shivay', 'male'),
#  ('izick', 'male'),
#  ('keanthony', 'male'),
#  ('lehi', 'male'),
#  ('almonza', 'male'),
#  ('parv', 'male'),
#  ('lanelda', 'female'),
#  ('cairi', 'female'),
#  ('tylissa', 'female'),
#  ('dyke', 'male'),
#  ('nikkisha', 'female'),
#  ('viet', 'male'),
#  ('ethelmae', 'female'),
#  ('clive', 'male'),
#  ('jeffro', 'male'),
#  ('alexsouza', 'male'),
#  ('kimkimberly', 'male'),
#  ('vardan', 'male'),
#  ('shenicka', 'female'),
#  ('zosia', 'female'),
#  ('aatto', 'male'),
#  ('elaiya', 'female'),
#  ('takis', 'male'),
#  ('lupe', 'male'),
#  ('weijia', 'female'),
#  ('tarak', 'male'),
#  ('hutchinson', 'male'),
#  ('madax', 'male'),
#  ('ethyn', 'male'),
#  ('xuenong', 'male'),
#  ('thaddea', 'female'),
#  ('jubi', 'female'),
#  ('glinnie', 'female'),
#  ('aafia', 'female'),
#  ('jacarter', 'male'),
#  ('ronneisha', 'female'),
#  ('bryanna', 'female'),
#  ('perlina', 'female'),
#  ('yoojin', 'male'),
#  ('jalivia', 'female'),
#  ('travaughn', 'male'),
#  ('sunan', 'male'),
#  ('jyun', 'male'),
#  ('virgen', 'female'),
#  ('kireina', 'female'),
#  ('hughie', 'male'),
#  ('astraeus', 'male'),
#  ('jonka', 'female'),
#  ('diamante', 'female'),
#  ('maryline', 'female'),
#  ('carmelia', 'female'),
#  ('gwennan', 'female'),
#  ('amear', 'male'),
#  ('siusun', 'male'),
#  ('kaelah', 'female'),
#  ('kiyohiro', 'male'),
#  ('purvan', 'male'),
#  ('zetta', 'female'),
#  ('flay', 'male'),
#  ('nicos', 'male'),
#  ('hildred', 'female'),
#  ('makaria', 'female'),
#  ('dakarri', 'male'),
#  ('myara', 'female'),
#  ('ambri', 'female'),
#  ('utae', 'female'),
#  ('tingji', 'male'),
#  ('sylviane', 'female'),
#  ('idlia', 'female'),
#  ('lediana', 'female'),
#  ('alexandrina', 'female'),
#  ('sufiya', 'female'),
#  ('duong', 'male'),
#  ('najea', 'female'),
#  ('ehrengard', 'female'),
#  ('loan', 'male'),
#  ('kleo', 'male'),
#  ('gautier', 'male'),
#  ('zelmarie', 'female'),
#  ('aubriona', 'female'),
#  ('anamile', 'female'),
#  ('lepanto', 'male'),
#  ('analize', 'female'),
#  ('joshua', 'male'),
#  ('arlos', 'male'),
#  ('diedri', 'female'),
#  ('anique', 'female'),
#  ('jonothan', 'male'),
#  ('idalou', 'female'),
#  ('alexandia', 'female'),
#  ('jefto', 'male'),
#  ('brendyn', 'male'),
#  ('lenleonard', 'male'),
#  ('breckynn', 'female'),
#  ('cynteria', 'female'),
#  ('tangee', 'female'),
#  ('socheata', 'female'),
#  ('iselys', 'female'),
#  ('katisha', 'female'),
#  ('friedbald', 'male'),
#  ('luzetta', 'female'),
#  ('ellet', 'male'),
#  ('aybike', 'male'),
#  ('mika', 'male'),
#  ('philly', 'male'),
#  ('priansh', 'male'),
#  ('burglind', 'female'),
#  ('loria', 'female'),
#  ('lilliah', 'female'),
#  ('jilliann', 'female'),
#  ('chaviv', 'male'),
#  ('travonne', 'male'),
#  ('rhone', 'male'),
#  ('celsa', 'female'),
#  ('genadij', 'male'),
#  ('frieda', 'female'),
#  ('heraclio', 'male'),
#  ('lejuan', 'male'),
#  ('hyunwoo', 'male'),
#  ('smiljana', 'female'),
#  ('artemas', 'male'),
#  ('claira', 'female'),
#  ('audrei', 'female'),
#  ('narsiso', 'male'),
#  ('jianqun', 'male'),
#  ('detavius', 'male'),
#  ('hucksley', 'male'),
#  ('yasniel', 'male'),
#  ('racha', 'female'),
#  ('tommie', 'male'),
#  ('jash', 'male'),
#  ('alair', 'female'),
#  ('omari', 'male'),
#  ('luzmar', 'female'),
#  ('veselko', 'male'),
#  ('ninghui', 'male'),
#  ('erinmarie', 'female'),
#  ('layth', 'male'),
#  ('dulaney', 'female'),
#  ('cansever', 'female'),
#  ('onas', 'male'),
#  ('farrad', 'male'),
#  ('byungok', 'female'),
#  ('tanjyot', 'female'),
#  ('tajane', 'female'),
#  ('dzion', 'male'),
#  ('mingrui', 'male'),
#  ('iosif', 'male'),
#  ('murile', 'female'),
#  ('herwig', 'male'),
#  ('zuley', 'female'),
#  ('aley', 'female'),
#  ('anniece', 'female'),
#  ('renxiang', 'male'),
#  ('bernadette', 'female'),
#  ('anusri', 'female'),
#  ('attila', 'female'),
#  ('deyanne', 'female'),
#  ('chans', 'male'),
#  ('iolia', 'female'),
#  ('nemesis', 'female'),
#  ('itzelt', 'female'),
#  ...]
